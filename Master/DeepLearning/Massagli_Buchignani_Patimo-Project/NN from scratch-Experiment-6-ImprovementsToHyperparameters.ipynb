# %% [markdown]
# # Experiment 6

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# download the dataset content from google drive to google colab vm (this is done for efficiency reasons)
# !cp -r /content/drive/MyDrive/CIDL_Project/dataset/preprocessed_annotations/preprocessed_annotations .
# !cp -r /content/drive/MyDrive/CIDL_Project/dataset/preprocessed_images/preprocessed_images .

# %%
import tensorflow as tf

# store the images using a keras utility
image_dataset = tf.keras.utils.image_dataset_from_directory(
    directory='./preprocessed_images',
    labels = None,
    label_mode=None,
    batch_size=None,
    color_mode='rgb',
    # specify the size of the images, all the images are rescaled to this size
    image_size=(128, 128),
    shuffle=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 1861 files belonging to 1 classes.

# %% [markdown]
# The functions in the next cell are an adaptation of the code used in the [Keras tutorial of RetinaNet](https://keras.io/examples/vision/retinanet/)

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ["without mask", "with mask"]

def visualize_image(image, figsize=(7, 7)):
    image = np.array(image, dtype=np.uint8)
    plt.figure()
    plt.axis("off")
    plt.imshow(image)
    return plt

def visualize_images(images, figsize=(7, 7)):
  for image in images:
    visualize_image(image, figsize)

def visualize_detections(
    image, box, label, figsize=(7, 7), linewidth=1, color=[0, 0, 1]
):
    # the function gets as input the image, the bounding box in xmin, ymin, xmax and ymax format and the label as an integer (0 or 1)
    plt = visualize_image(image)
    ax = plt.gca()
    text = "{}:".format(labels[label])
    x1, y1, x2, y2 = box
    w, h = x2 - x1, y2 - y1
    patch = plt.Rectangle(
        [x1, y1], w, h, fill=False, edgecolor=color, linewidth=linewidth
    )
    ax.add_patch(patch)
    ax.text(
        x1,
        y1,
        text,
        bbox={"facecolor": color, "alpha": 0.4},
        clip_box=ax.clipbox,
        clip_on=True,
    )
    plt.show()
    return ax

# %%
def rescale_bbox(image_shape, bbox):
  # bbox is a tensor with the normalized coordinates of the bounding box expressed in xmin, ymin, xmax, ymax format
  # the function denormalizes the coordinates and returns the corresponding tensor
  return tf.stack(
        [
            bbox[0] * image_shape[1],
            bbox[1] * image_shape[0],
            bbox[2] * image_shape[1],
            bbox[3] * image_shape[0]
        ])

# %% [markdown]
# The functions in the next cell are an adaptation of the code used in the [Keras tutorial of RetinaNet](https://keras.io/examples/vision/retinanet/)
#
# The coordinates of the bounding boxes can be expressed in two formats:
# *   xmin, ymin, xmax, ymax (minmax for short)
# *   xcenter, ycenter, width, height (xywh for short)
#
# The two functions below convert a format to the other one and viceversa.
#
# Both are needed because to visualize them we need the first format, while the format used to train the network is the second

# %%
def convert_to_xywh(boxes):
    return tf.concat(
        [(boxes[..., :2] + boxes[..., 2:]) / 2.0, boxes[..., 2:] - boxes[..., :2]],
        axis=-1,
    )

def convert_to_minmax(boxes):
    return tf.concat(
        [boxes[..., :2] - boxes[..., 2:] / 2.0, boxes[..., :2] + boxes[..., 2:] / 2.0],
        axis=-1,
    )

# %%
def flip_horizontal(image, boxes):
    # we flip the image given in input and modify accordingly the bounding boxes, which are here expressed in xywh
    flipped_image = tf.image.flip_left_right(image)
    flipped_boxes = tf.stack(
        [1 - boxes[0], boxes[1], boxes[2], boxes[3]], axis=-1
    )
    return flipped_image, flipped_boxes

# %% [markdown]
# The next function is the function that takes the raw data from the ground truth files and converts it to a format that will be used during the training and test of the network.

# %%
def preprocess_data(sample):
    # sample is a dictionary containing all the relevant information about an image
    # normalize each coordinate on the basis of the original width and height of the image
    normalized_xmin = sample["xmin"] / sample["width"]
    normalized_ymin = sample["ymin"] / sample["height"]
    normalized_xmax = sample["xmax"] / sample["width"]
    normalized_ymax = sample["ymax"] / sample["height"]
    # convert the list of coordinates into a tensor and in xywh format
    bounding_box = [normalized_xmin, normalized_ymin, normalized_xmax, normalized_ymax]
    bboxes = tf.convert_to_tensor(bounding_box)
    bboxes = convert_to_xywh(bboxes)
    label = tf.convert_to_tensor(sample["label"], dtype=tf.float32)
    ground_truth = tf.stack(
        [
            bboxes[0],
            bboxes[1],
            bboxes[2],
            bboxes[3]
        ],
        axis=-1,
    )
    return ground_truth, label

# %% [markdown]
# In the next cell we take each image, we parse the relative annotation file to get the relevant information and we create the dataset

# %%
import os

path = "preprocessed_annotations"
i = 0

annotations = os.listdir(path)
# sorting in lexicographic order is needed to match image ordering
annotations.sort()

list_of_features = []
list_of_bboxes = []
list_of_labels = []

for image in image_dataset:
  
  # get the path of the annotation file corresponding to the image
  file_name = annotations[i]
  file_path = os.path.join(path, file_name)

  sample = {}
  
  with open(file_path, 'r') as f:

    # fill the dictionary with the relevant information
    sample["width"] = int(f.readline())
    sample["height"] = int(f.readline())
    sample["xmin"] = int(f.readline())
    sample["ymin"] = int(f.readline())
    sample["xmax"] = int(f.readline())
    sample["ymax"] = int(f.readline())
    # label is here normalized as a value contained in the set {0, 1}.
    # In the annotation file 1 stands for class "without mask" and 2 stands for class "with mask", here we set 0 as "without mask" and 1 as "with mask"
    sample["label"] = int(f.readline()) - 1
    bounding_box, label = preprocess_data(sample)    
  list_of_features.append(image)
  list_of_bboxes.append(bounding_box)
  list_of_labels.append(label)
  # if the image belongs to class "withouth mask" generate the flipped image to augment the dataset
  if sample["label"] == 0:
    flipped_image, flipped_bbox = flip_horizontal(image, bounding_box)
    list_of_features.append(flipped_image)
    list_of_bboxes.append(flipped_bbox)
    list_of_labels.append(label)
  i = i + 1
  if (i % 200 == 0):
    print(i)

feature_tensor = tf.convert_to_tensor(list_of_features)
bounding_box_tensor = tf.convert_to_tensor(list_of_bboxes)
labels_tensor = tf.convert_to_tensor(list_of_labels)

# set test size
test_set_size = int(np.floor(feature_tensor.shape[0]*0.2))
# Out:
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800

# %%
# shuffle the three tensors in such a way the elements remained coupled across tensors
random_seed = 100
tf.random.set_seed(random_seed)
feature_tensor = tf.random.shuffle(feature_tensor)
tf.random.set_seed(random_seed)
bounding_box_tensor = tf.random.shuffle(bounding_box_tensor)
tf.random.set_seed(random_seed)
labels_tensor = tf.random.shuffle(labels_tensor)

# %%
# verify that each bounding box and each label is still at the same index as the relative image
index = 150
bbox = convert_to_minmax(bounding_box_tensor[index])
scaled_bbox = rescale_bbox(feature_tensor[index].shape, bbox)
visualize_detections(feature_tensor[index], scaled_bbox, int(labels_tensor[index].numpy()))

# %%
# split in training set and test set
feature_test_set = feature_tensor[:test_set_size]
feature_tensor = feature_tensor[test_set_size:]
bounding_box_test_set = bounding_box_tensor[:test_set_size]
bounding_box_tensor = bounding_box_tensor[test_set_size:]
labels_test_set = labels_tensor[:test_set_size]
labels_tensor = labels_tensor[test_set_size:]

# %% [markdown]
# The function in the next cell is an adaptation of the code used in the [Keras tutorial of RetinaNet](https://keras.io/examples/vision/retinanet/)
#
# The function is used as a callback metric during training and test for measuring the performance of the regression head

# %%
def IoU_metric(y_true, y_pred):
    # y_true is a tensor representing the ground truth bounding boxes for a given batch of samples (in format xywh)
    # y_pred is a tensor representing the predicted bounding boxes for the same batch of samples (in format xywh)
    # the function computes the IoU score for each couple (ground truth bounding box, predicted bounding box)
    boxes1_corners = convert_to_minmax(y_true)
    boxes2_corners = convert_to_minmax(y_pred)

    # compute the intersection area
    lu = tf.maximum(boxes1_corners[:, :2], boxes2_corners[:, :2])
    rd = tf.minimum(boxes1_corners[:, 2:], boxes2_corners[:, 2:])
    intersection = tf.maximum(0.0, rd - lu)
    intersection_area = intersection[:, 0] * intersection[:, 1]

    # compute the union area
    boxes1_area = y_true[:, 2] * y_true[:, 3]
    boxes2_area = y_pred[:, 2] * y_pred[:, 3]  
    union_area = tf.maximum(
        boxes1_area + boxes2_area - intersection_area, 1e-8
    )

    # compute IoU
    return tf.clip_by_value(intersection_area / union_area, 0.0, 1.0)

# %%
from tensorflow import keras

# instantiate the model
input = keras.Input(shape=(128,128,3), name="input")
model = keras.layers.Conv2D(32, (3, 3), activation='relu')(input)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(64, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(128, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(256, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Flatten()(model)
dropout_cls = keras.layers.Dropout(0.8)(model)
dropout_box = keras.layers.Dropout(0.7)(model)
dense_cls = keras.layers.Dense(32, activation='relu')(dropout_cls)
classification_head = keras.layers.Dense(1, activation='sigmoid', name="labels")(dense_cls)
regression_head = keras.layers.Dense(4, activation='sigmoid', name="bounding_box")(dropout_box)

# %%
# define input and outputs of the model
model = keras.Model(
    inputs=input,
    outputs=[classification_head, regression_head],
)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_28 (Conv2D)             (None, 126, 126, 32  896         ['input[0][0]']
#                                 )
#
#  max_pooling2d_28 (MaxPooling2D  (None, 63, 63, 32)  0           ['conv2d_28[0][0]']
#  )
#
#  conv2d_29 (Conv2D)             (None, 61, 61, 64)   18496       ['max_pooling2d_28[0][0]']
#
#  max_pooling2d_29 (MaxPooling2D  (None, 30, 30, 64)  0           ['conv2d_29[0][0]']
#  )
#
#  conv2d_30 (Conv2D)             (None, 28, 28, 128)  73856       ['max_pooling2d_29[0][0]']
#
#  max_pooling2d_30 (MaxPooling2D  (None, 14, 14, 128)  0          ['conv2d_30[0][0]']
#  )
#
#  conv2d_31 (Conv2D)             (None, 12, 12, 256)  295168      ['max_pooling2d_30[0][0]']
#
#  max_pooling2d_31 (MaxPooling2D  (None, 6, 6, 256)   0           ['conv2d_31[0][0]']
#  )
#
#  flatten_7 (Flatten)            (None, 9216)         0           ['max_pooling2d_31[0][0]']
#
#  dropout_14 (Dropout)           (None, 9216)         0           ['flatten_7[0][0]']
#
#  dense_6 (Dense)                (None, 32)           294944      ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)           (None, 9216)         0           ['flatten_7[0][0]']
#
#  labels (Dense)                 (None, 1)            33          ['dense_6[0][0]']
#
#  bounding_box (Dense)           (None, 4)            36868       ['dropout_15[0][0]']
#
# ==================================================================================================
# Total params: 720,261
# Trainable params: 720,261
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# compile the model
model.compile(
    optimizer=keras.optimizers.RMSprop(1e-3),

    # define which loss to use for each head of the network
    loss={
        "bounding_box": keras.losses.MeanSquaredError(),
        "labels": keras.losses.BinaryCrossentropy(),
    },

    # the total loss is a linear combination of the two losses of the network, here we define the weights of each loss
    loss_weights={"labels": 1.0, "bounding_box": 10.0},

    # define which metrics to use for each head of the network, here we select our custom callback function IoU_metric() for the regression head
    metrics={'labels':'accuracy', 'bounding_box': [IoU_metric]}
)

# this is done to implement early stopping
model_dir = "models/"
experiment = "scratch_cnn_exp6.h5"
save_path = os.path.join(model_dir, experiment)

callbacks_list = [
    keras.callbacks.ModelCheckpoint(
      filepath=save_path,
      monitor="val_loss",
      verbose=1,
      save_best_only=True),

    # the ReduceLROnPlateau reduce adaptively the learning rate when the validation loss is not decreasing anymore
    keras.callbacks.ReduceLROnPlateau(verbose=1, patience=2, factor=0.5)
]

# %%
history = model.fit(
              {"input": feature_tensor},
              {"labels": labels_tensor, "bounding_box": bounding_box_tensor},
              epochs = 30,
              batch_size=16,
              validation_split=0.2,
              shuffle=True,
              callbacks = callbacks_list
          )
# Out:
# Epoch 1/30
# 86/86 [==============================] - ETA: 0s - loss: 2.3062 - labels_loss: 1.4644 - bounding_box_loss: 0.0842 - labels_accuracy: 0.7161 - bounding_box_IoU_metric: 0.0461
# Epoch 1: val_loss improved from inf to 0.94134, saving model to models/scratch_cnn_exp7.h5
# 86/86 [==============================] - 54s 599ms/step - loss: 2.3062 - labels_loss: 1.4644 - bounding_box_loss: 0.0842 - labels_accuracy: 0.7161 - bounding_box_IoU_metric: 0.0461 - val_loss: 0.9413 - val_labels_loss: 0.5754 - val_bounding_box_loss: 0.0366 - val_labels_accuracy: 0.7551 - val_bounding_box_IoU_metric: 0.0440 - lr: 0.0010
# Epoch 2/30
# 86/86 [==============================] - ETA: 0s - loss: 0.8757 - labels_loss: 0.6009 - bounding_box_loss: 0.0275 - labels_accuracy: 0.7372 - bounding_box_IoU_metric: 0.1110
# Epoch 2: val_loss improved from 0.94134 to 0.81516, saving model to models/scratch_cnn_exp7.h5
# 86/86 [==============================] - 52s 604ms/step - loss: 0.8757 - labels_loss: 0.6009 - bounding_box_loss: 0.0275 - labels_accuracy: 0.7372 - bounding_box_IoU_metric: 0.1110 - val_loss: 0.8152 - val_labels_loss: 0.5509 - val_bounding_box_loss: 0.0264 - val_labels_accuracy: 0.7551 - val_bounding_box_IoU_metric: 0.0635 - lr: 0.0010
# Epoch 3/30
# 86/86 [==============================] - ETA: 0s - loss: 0.8556 - labels_loss: 0.6105 - bounding_box_loss: 0.0245 - labels_accuracy: 0.7372 - bounding_box_IoU_metric: 0.1268
# Epoch 3: val_loss improved from 0.81516 to 0.74337, saving model to models/scratch_cnn_exp7.h5
# 86/86 [==============================] - 53s 614ms/step - loss: 0.8556 - labels_loss: 0.6105 - bounding_box_loss: 0.0245 - labels_accuracy: 0.7372 - bounding_box_IoU_metric: 0.1268 - val_loss: 0.7434 - val_labels_loss: 0.5431 - val_bounding_box_loss: 0.0200 - val_labels_accuracy: 0.7551 - val_bounding_box_IoU_metric: 0.1856 - lr: 0.0010
# Epoch 4/30
# 86/86 [==============================] - ETA: 0s - loss: 0.8172 - labels_loss: 0.5953 - bounding_box_loss: 0.0222 - labels_accuracy: 0.7372 - bounding_box_IoU_metric: 0.1430
# Epoch 4: val_loss did not improve from 0.74337
# 86/86 [==============================] - 51s 588ms/step - loss: 0.8172 - labels_loss: 0.5953 - bounding_box_loss: 0.0222 - labels_accuracy: 0.7372 - bounding_box_IoU_metric: 0.1430 - val_loss: 0.7574 - val_labels_loss: 0.5416 - val_bounding_box_loss: 0.0216 - val_labels_accuracy: 0.7551 - val_bounding_box_IoU_metric: 0.1165 - lr: 0.0010
# Epoch 5/30
# 86/86 [==============================] - ETA: 0s - loss: 0.7611 - labels_loss: 0.5541 - bounding_box_loss: 0.0207 - labels_accuracy: 0.7372 - bounding_box_IoU_metric: 0.1599
# Epoch 5: val_loss improved from 0.74337 to 0.70137, saving model to models/scratch_cnn_exp7.h5
# 86/86 [==============================] - 51s 593ms/step - loss: 0.7611 - labels_loss: 0.5541 - bounding_box_loss: 0.0207 - labels_accuracy: 0.7372 - bounding_box_IoU_metric: 0.1599 - val_loss: 0.7014 - val_labels_loss: 0.5315 - val_bounding_box_loss: 0.0170 - val_labels_accuracy: 0.7551 - val_bounding_box_IoU_metric: 0.1786 - lr: 0.0010
# Epoch 6/30
# 86/86 [==============================] - ETA: 0s - loss: 0.7496 - labels_loss: 0.5551 - bounding_box_loss: 0.0194 - labels_accuracy: 0.7372 - bounding_box_IoU_metric: 0.1642
# Epoch 6: val_loss did not improve from 0.70137
# 86/86 [==============================] - 51s 595ms/step - loss: 0.7496 - labels_loss: 0.5551 - bounding_box_loss: 0.0194 - labels_accuracy: 0.7372 - bounding_box_IoU_metric: 0.1642 - val_loss: 0.7281 - val_labels_loss: 0.5473 - val_bounding_box_loss: 0.0181 - val_labels_accuracy: 0.7551 - val_bounding_box_IoU_metric: 0.1378 - lr: 0.0010
# Epoch 7/30
# 86/86 [==============================] - ETA: 0s - loss: 0.7188 - labels_loss: 0.5260 - bounding_box_loss: 0.0193 - labels_accuracy: 0.7423 - bounding_box_IoU_metric: 0.1670
# Epoch 7: val_loss did not improve from 0.70137
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 86/86 [==============================] - 53s 616ms/step - loss: 0.7188 - labels_loss: 0.5260 - bounding_box_loss: 0.0193 - labels_accuracy: 0.7423 - bounding_box_IoU_metric: 0.1670 - val_loss: 0.8062 - val_labels_loss: 0.6195 - val_bounding_box_loss: 0.0187 - val_labels_accuracy: 0.7580 - val_bounding_box_IoU_metric: 0.1580 - lr: 0.0010
# Epoch 8/30
# 86/86 [==============================] - ETA: 0s - loss: 0.6633 - labels_loss: 0.4971 - bounding_box_loss: 0.0166 - labels_accuracy: 0.7416 - bounding_box_IoU_metric: 0.1847
# Epoch 8: val_loss did not improve from 0.70137
# 86/86 [==============================] - 51s 589ms/step - loss: 0.6633 - labels_loss: 0.4971 - bounding_box_loss: 0.0166 - labels_accuracy: 0.7416 - bounding_box_IoU_metric: 0.1847 - val_loss: 0.7499 - val_labels_loss: 0.5859 - val_bounding_box_loss: 0.0164 - val_labels_accuracy: 0.7609 - val_bounding_box_IoU_metric: 0.1951 - lr: 5.0000e-04
# Epoch 9/30
# 86/86 [==============================] - ETA: 0s - loss: 0.6263 - labels_loss: 0.4665 - bounding_box_loss: 0.0160 - labels_accuracy: 0.7474 - bounding_box_IoU_metric: 0.1876
# Epoch 9: val_loss did not improve from 0.70137
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 86/86 [==============================] - 51s 591ms/step - loss: 0.6263 - labels_loss: 0.4665 - bounding_box_loss: 0.0160 - labels_accuracy: 0.7474 - bounding_box_IoU_metric: 0.1876 - val_loss: 0.7133 - val_labels_loss: 0.5642 - val_bounding_box_loss: 0.0149 - val_labels_accuracy: 0.7551 - val_bounding_box_IoU_metric: 0.2006 - lr: 5.0000e-04
# Epoch 10/30
# 86/86 [==============================] - ETA: 0s - loss: 0.5808 - labels_loss: 0.4334 - bounding_box_loss: 0.0147 - labels_accuracy: 0.7577 - bounding_box_IoU_metric: 0.1968
# Epoch 10: val_loss improved from 0.70137 to 0.65759, saving model to models/scratch_cnn_exp7.h5
# 86/86 [==============================] - 51s 591ms/step - loss: 0.5808 - labels_loss: 0.4334 - bounding_box_loss: 0.0147 - labels_accuracy: 0.7577 - bounding_box_IoU_metric: 0.1968 - val_loss: 0.6576 - val_labels_loss: 0.5146 - val_bounding_box_loss: 0.0143 - val_labels_accuracy: 0.7813 - val_bounding_box_IoU_metric: 0.2130 - lr: 2.5000e-04
# Epoch 11/30
# 86/86 [==============================] - ETA: 0s - loss: 0.5636 - labels_loss: 0.4250 - bounding_box_loss: 0.0139 - labels_accuracy: 0.7715 - bounding_box_IoU_metric: 0.2166
# Epoch 11: val_loss did not improve from 0.65759
# 86/86 [==============================] - 53s 612ms/step - loss: 0.5636 - labels_loss: 0.4250 - bounding_box_loss: 0.0139 - labels_accuracy: 0.7715 - bounding_box_IoU_metric: 0.2166 - val_loss: 0.6681 - val_labels_loss: 0.5271 - val_bounding_box_loss: 0.0141 - val_labels_accuracy: 0.7784 - val_bounding_box_IoU_metric: 0.2247 - lr: 2.5000e-04
# Epoch 12/30
# 86/86 [==============================] - ETA: 0s - loss: 0.5394 - labels_loss: 0.4030 - bounding_box_loss: 0.0136 - labels_accuracy: 0.7810 - bounding_box_IoU_metric: 0.2116
# Epoch 12: val_loss did not improve from 0.65759
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 86/86 [==============================] - 51s 589ms/step - loss: 0.5394 - labels_loss: 0.4030 - bounding_box_loss: 0.0136 - labels_accuracy: 0.7810 - bounding_box_IoU_metric: 0.2116 - val_loss: 0.7944 - val_labels_loss: 0.6473 - val_bounding_box_loss: 0.0147 - val_labels_accuracy: 0.7755 - val_bounding_box_IoU_metric: 0.2173 - lr: 2.5000e-04
# Epoch 13/30
# 86/86 [==============================] - ETA: 0s - loss: 0.5125 - labels_loss: 0.3820 - bounding_box_loss: 0.0130 - labels_accuracy: 0.7876 - bounding_box_IoU_metric: 0.2200
# Epoch 13: val_loss did not improve from 0.65759
# 86/86 [==============================] - 51s 593ms/step - loss: 0.5125 - labels_loss: 0.3820 - bounding_box_loss: 0.0130 - labels_accuracy: 0.7876 - bounding_box_IoU_metric: 0.2200 - val_loss: 0.7021 - val_labels_loss: 0.5615 - val_bounding_box_loss: 0.0141 - val_labels_accuracy: 0.7813 - val_bounding_box_IoU_metric: 0.2206 - lr: 1.2500e-04
# Epoch 14/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4978 - labels_loss: 0.3728 - bounding_box_loss: 0.0125 - labels_accuracy: 0.8015 - bounding_box_IoU_metric: 0.2239
# Epoch 14: val_loss did not improve from 0.65759
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 86/86 [==============================] - 51s 588ms/step - loss: 0.4978 - labels_loss: 0.3728 - bounding_box_loss: 0.0125 - labels_accuracy: 0.8015 - bounding_box_IoU_metric: 0.2239 - val_loss: 0.7031 - val_labels_loss: 0.5652 - val_bounding_box_loss: 0.0138 - val_labels_accuracy: 0.7872 - val_bounding_box_IoU_metric: 0.2231 - lr: 1.2500e-04
# Epoch 15/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4828 - labels_loss: 0.3602 - bounding_box_loss: 0.0123 - labels_accuracy: 0.8124 - bounding_box_IoU_metric: 0.2245
# Epoch 15: val_loss did not improve from 0.65759
# 86/86 [==============================] - 53s 614ms/step - loss: 0.4828 - labels_loss: 0.3602 - bounding_box_loss: 0.0123 - labels_accuracy: 0.8124 - bounding_box_IoU_metric: 0.2245 - val_loss: 0.6954 - val_labels_loss: 0.5593 - val_bounding_box_loss: 0.0136 - val_labels_accuracy: 0.7901 - val_bounding_box_IoU_metric: 0.2293 - lr: 6.2500e-05
# Epoch 16/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4705 - labels_loss: 0.3482 - bounding_box_loss: 0.0122 - labels_accuracy: 0.8036 - bounding_box_IoU_metric: 0.2274
# Epoch 16: val_loss did not improve from 0.65759
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 86/86 [==============================] - 51s 588ms/step - loss: 0.4705 - labels_loss: 0.3482 - bounding_box_loss: 0.0122 - labels_accuracy: 0.8036 - bounding_box_IoU_metric: 0.2274 - val_loss: 0.7155 - val_labels_loss: 0.5777 - val_bounding_box_loss: 0.0138 - val_labels_accuracy: 0.7901 - val_bounding_box_IoU_metric: 0.2230 - lr: 6.2500e-05
# Epoch 17/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4607 - labels_loss: 0.3411 - bounding_box_loss: 0.0120 - labels_accuracy: 0.8234 - bounding_box_IoU_metric: 0.2275
# Epoch 17: val_loss did not improve from 0.65759
# 86/86 [==============================] - 51s 588ms/step - loss: 0.4607 - labels_loss: 0.3411 - bounding_box_loss: 0.0120 - labels_accuracy: 0.8234 - bounding_box_IoU_metric: 0.2275 - val_loss: 0.7198 - val_labels_loss: 0.5824 - val_bounding_box_loss: 0.0137 - val_labels_accuracy: 0.7930 - val_bounding_box_IoU_metric: 0.2271 - lr: 3.1250e-05
# Epoch 18/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4620 - labels_loss: 0.3439 - bounding_box_loss: 0.0118 - labels_accuracy: 0.8190 - bounding_box_IoU_metric: 0.2313
# Epoch 18: val_loss did not improve from 0.65759
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 86/86 [==============================] - 50s 587ms/step - loss: 0.4620 - labels_loss: 0.3439 - bounding_box_loss: 0.0118 - labels_accuracy: 0.8190 - bounding_box_IoU_metric: 0.2313 - val_loss: 0.7250 - val_labels_loss: 0.5893 - val_bounding_box_loss: 0.0136 - val_labels_accuracy: 0.7843 - val_bounding_box_IoU_metric: 0.2268 - lr: 3.1250e-05
# Epoch 19/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4614 - labels_loss: 0.3413 - bounding_box_loss: 0.0120 - labels_accuracy: 0.8161 - bounding_box_IoU_metric: 0.2322
# Epoch 19: val_loss did not improve from 0.65759
# 86/86 [==============================] - 57s 658ms/step - loss: 0.4614 - labels_loss: 0.3413 - bounding_box_loss: 0.0120 - labels_accuracy: 0.8161 - bounding_box_IoU_metric: 0.2322 - val_loss: 0.7226 - val_labels_loss: 0.5871 - val_bounding_box_loss: 0.0136 - val_labels_accuracy: 0.7930 - val_bounding_box_IoU_metric: 0.2282 - lr: 1.5625e-05
# Epoch 20/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4626 - labels_loss: 0.3427 - bounding_box_loss: 0.0120 - labels_accuracy: 0.8241 - bounding_box_IoU_metric: 0.2280
# Epoch 20: val_loss did not improve from 0.65759
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 86/86 [==============================] - 55s 643ms/step - loss: 0.4626 - labels_loss: 0.3427 - bounding_box_loss: 0.0120 - labels_accuracy: 0.8241 - bounding_box_IoU_metric: 0.2280 - val_loss: 0.7242 - val_labels_loss: 0.5886 - val_bounding_box_loss: 0.0136 - val_labels_accuracy: 0.7930 - val_bounding_box_IoU_metric: 0.2290 - lr: 1.5625e-05
# Epoch 21/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4532 - labels_loss: 0.3359 - bounding_box_loss: 0.0117 - labels_accuracy: 0.8219 - bounding_box_IoU_metric: 0.2323
# Epoch 21: val_loss did not improve from 0.65759
# 86/86 [==============================] - 53s 616ms/step - loss: 0.4532 - labels_loss: 0.3359 - bounding_box_loss: 0.0117 - labels_accuracy: 0.8219 - bounding_box_IoU_metric: 0.2323 - val_loss: 0.7172 - val_labels_loss: 0.5820 - val_bounding_box_loss: 0.0135 - val_labels_accuracy: 0.7959 - val_bounding_box_IoU_metric: 0.2306 - lr: 7.8125e-06
# Epoch 22/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4568 - labels_loss: 0.3405 - bounding_box_loss: 0.0116 - labels_accuracy: 0.8153 - bounding_box_IoU_metric: 0.2360
# Epoch 22: val_loss did not improve from 0.65759
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 86/86 [==============================] - 53s 612ms/step - loss: 0.4568 - labels_loss: 0.3405 - bounding_box_loss: 0.0116 - labels_accuracy: 0.8153 - bounding_box_IoU_metric: 0.2360 - val_loss: 0.7208 - val_labels_loss: 0.5855 - val_bounding_box_loss: 0.0135 - val_labels_accuracy: 0.7959 - val_bounding_box_IoU_metric: 0.2304 - lr: 7.8125e-06
# Epoch 23/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4517 - labels_loss: 0.3345 - bounding_box_loss: 0.0117 - labels_accuracy: 0.8234 - bounding_box_IoU_metric: 0.2349
# Epoch 23: val_loss did not improve from 0.65759
# 86/86 [==============================] - 54s 625ms/step - loss: 0.4517 - labels_loss: 0.3345 - bounding_box_loss: 0.0117 - labels_accuracy: 0.8234 - bounding_box_IoU_metric: 0.2349 - val_loss: 0.7249 - val_labels_loss: 0.5894 - val_bounding_box_loss: 0.0135 - val_labels_accuracy: 0.7930 - val_bounding_box_IoU_metric: 0.2299 - lr: 3.9063e-06
# Epoch 24/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4510 - labels_loss: 0.3327 - bounding_box_loss: 0.0118 - labels_accuracy: 0.8285 - bounding_box_IoU_metric: 0.2304
# Epoch 24: val_loss did not improve from 0.65759
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 86/86 [==============================] - 51s 597ms/step - loss: 0.4510 - labels_loss: 0.3327 - bounding_box_loss: 0.0118 - labels_accuracy: 0.8285 - bounding_box_IoU_metric: 0.2304 - val_loss: 0.7241 - val_labels_loss: 0.5888 - val_bounding_box_loss: 0.0135 - val_labels_accuracy: 0.7930 - val_bounding_box_IoU_metric: 0.2300 - lr: 3.9063e-06
# Epoch 25/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4511 - labels_loss: 0.3322 - bounding_box_loss: 0.0119 - labels_accuracy: 0.8168 - bounding_box_IoU_metric: 0.2350
# Epoch 25: val_loss did not improve from 0.65759
# 86/86 [==============================] - 51s 597ms/step - loss: 0.4511 - labels_loss: 0.3322 - bounding_box_loss: 0.0119 - labels_accuracy: 0.8168 - bounding_box_IoU_metric: 0.2350 - val_loss: 0.7237 - val_labels_loss: 0.5884 - val_bounding_box_loss: 0.0135 - val_labels_accuracy: 0.7930 - val_bounding_box_IoU_metric: 0.2294 - lr: 1.9531e-06
# Epoch 26/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4464 - labels_loss: 0.3284 - bounding_box_loss: 0.0118 - labels_accuracy: 0.8270 - bounding_box_IoU_metric: 0.2319
# Epoch 26: val_loss did not improve from 0.65759
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 86/86 [==============================] - 52s 600ms/step - loss: 0.4464 - labels_loss: 0.3284 - bounding_box_loss: 0.0118 - labels_accuracy: 0.8270 - bounding_box_IoU_metric: 0.2319 - val_loss: 0.7235 - val_labels_loss: 0.5882 - val_bounding_box_loss: 0.0135 - val_labels_accuracy: 0.7959 - val_bounding_box_IoU_metric: 0.2297 - lr: 1.9531e-06
# Epoch 27/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4464 - labels_loss: 0.3308 - bounding_box_loss: 0.0116 - labels_accuracy: 0.8234 - bounding_box_IoU_metric: 0.2329
# Epoch 27: val_loss did not improve from 0.65759
# 86/86 [==============================] - 54s 625ms/step - loss: 0.4464 - labels_loss: 0.3308 - bounding_box_loss: 0.0116 - labels_accuracy: 0.8234 - bounding_box_IoU_metric: 0.2329 - val_loss: 0.7239 - val_labels_loss: 0.5887 - val_bounding_box_loss: 0.0135 - val_labels_accuracy: 0.7930 - val_bounding_box_IoU_metric: 0.2299 - lr: 9.7656e-07
# Epoch 28/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4432 - labels_loss: 0.3260 - bounding_box_loss: 0.0117 - labels_accuracy: 0.8270 - bounding_box_IoU_metric: 0.2309
# Epoch 28: val_loss did not improve from 0.65759
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 86/86 [==============================] - 51s 599ms/step - loss: 0.4432 - labels_loss: 0.3260 - bounding_box_loss: 0.0117 - labels_accuracy: 0.8270 - bounding_box_IoU_metric: 0.2309 - val_loss: 0.7245 - val_labels_loss: 0.5893 - val_bounding_box_loss: 0.0135 - val_labels_accuracy: 0.7930 - val_bounding_box_IoU_metric: 0.2300 - lr: 9.7656e-07
# Epoch 29/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4480 - labels_loss: 0.3315 - bounding_box_loss: 0.0116 - labels_accuracy: 0.8307 - bounding_box_IoU_metric: 0.2381
# Epoch 29: val_loss did not improve from 0.65759
# 86/86 [==============================] - 51s 594ms/step - loss: 0.4480 - labels_loss: 0.3315 - bounding_box_loss: 0.0116 - labels_accuracy: 0.8307 - bounding_box_IoU_metric: 0.2381 - val_loss: 0.7243 - val_labels_loss: 0.5891 - val_bounding_box_loss: 0.0135 - val_labels_accuracy: 0.7930 - val_bounding_box_IoU_metric: 0.2300 - lr: 4.8828e-07
# Epoch 30/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4469 - labels_loss: 0.3298 - bounding_box_loss: 0.0117 - labels_accuracy: 0.8299 - bounding_box_IoU_metric: 0.2367
# Epoch 30: val_loss did not improve from 0.65759
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 86/86 [==============================] - 51s 590ms/step - loss: 0.4469 - labels_loss: 0.3298 - bounding_box_loss: 0.0117 - labels_accuracy: 0.8299 - bounding_box_IoU_metric: 0.2367 - val_loss: 0.7242 - val_labels_loss: 0.5890 - val_bounding_box_loss: 0.0135 - val_labels_accuracy: 0.7930 - val_bounding_box_IoU_metric: 0.2300 - lr: 4.8828e-07

# %%
#plot the history of the training

plt.figure(figsize=(12,5))
plt.title('labels loss')
plt.plot(history.history['labels_loss'],'bo-',label = 'train_labels_loss')
plt.plot(history.history['val_labels_loss'],'b-',label = 'val_labels_loss')
plt.ylim(0,1)
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('bbox loss')
plt.plot(history.history['bounding_box_loss'],'bo-',label = 'train_bounding_box_loss')
plt.plot(history.history['val_bounding_box_loss'],'b-',label = 'val_bounding_box_loss')
plt.ylim(0,0.04)
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('total loss')
plt.plot(history.history['loss'],'bo-',label = 'train_loss')
plt.plot(history.history['val_loss'],'b-',label = 'val_loss')
plt.ylim(0,2)
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('accuracy')
plt.plot(history.history['labels_accuracy'],'bo-',label = 'train_labels_accuracy')
plt.plot(history.history['val_labels_accuracy'],'b-',label = 'val_labels_accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('IoU scaled in [0,1]')
plt.plot(history.history['bounding_box_IoU_metric'],'bo-',label = 'train_bounding_box_IoU_metric')
plt.plot(history.history['val_bounding_box_IoU_metric'],'b-',label = 'val_bounding_box_IoU_metric')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model

# delete the current model
del model

# load the model saved by the early stopping callback
model = load_model(os.path.join(model_dir, experiment), custom_objects={"IoU_metric": IoU_metric})

#evaluate the model on the test set
model.evaluate({"input": feature_test_set},
               {"labels": labels_test_set, "bounding_box": bounding_box_test_set}, 
               return_dict=True)
# Out:
# 14/14 [==============================] - 4s 283ms/step - loss: 0.6479 - labels_loss: 0.4976 - bounding_box_loss: 0.0150 - labels_accuracy: 0.7757 - bounding_box_IoU_metric: 0.2106
# {'loss': 0.6478906869888306,
#  'labels_loss': 0.49759361147880554,
#  'bounding_box_loss': 0.01502972561866045,
#  'labels_accuracy': 0.7757009267807007,
#  'bounding_box_IoU_metric': 0.21056120097637177}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# create and plot the confusion matrix
predictions = model(feature_test_set)
result = confusion_matrix(labels_test_set, tf.cast(tf.math.round(predictions[0]), dtype=tf.int32), normalize='pred')
disp = ConfusionMatrixDisplay(confusion_matrix=result, display_labels=['without mask', 'with mask'])
disp.plot()
plt.show()

# %%
# save the model to google drive
# !cp ./models/scratch_cnn_exp6.h5 /content/drive/MyDrive/CIDL_Project/models/

# %%
# verify that the model was uploaded to drive
drive_dir_model = "/content/drive/MyDrive/CIDL_Project/models/"
experiment = "scratch_cnn_exp6.h5"
model = load_model(os.path.join(drive_dir_model, experiment), custom_objects={"IoU_metric": IoU_metric})
model.evaluate({"input": feature_test_set},
               {"labels": tf.keras.utils.to_categorical(labels_test_set), "bounding_box": bounding_box_test_set}, 
               return_dict=True)
