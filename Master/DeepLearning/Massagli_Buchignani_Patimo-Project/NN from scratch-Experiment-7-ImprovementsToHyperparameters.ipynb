# %% [markdown]
# # Experiment 7

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# download the dataset content from google drive to google colab vm (this is done for efficiency reasons)
# !cp -r /content/drive/MyDrive/CIDL_Project/dataset/preprocessed_annotations/preprocessed_annotations .
# !cp -r /content/drive/MyDrive/CIDL_Project/dataset/preprocessed_images/preprocessed_images .

# %%
import tensorflow as tf

# store the images using a keras utility
image_dataset = tf.keras.utils.image_dataset_from_directory(
    directory='./preprocessed_images',
    labels = None,
    label_mode=None,
    batch_size=None,
    color_mode='rgb',
    # specify the size of the images, all the images are rescaled to this size
    image_size=(128, 128),
    shuffle=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 1861 files belonging to 1 classes.

# %% [markdown]
# The functions in the next cell are an adaptation of the code used in the [Keras tutorial of RetinaNet](https://keras.io/examples/vision/retinanet/)

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ["without mask", "with mask"]

def visualize_image(image, figsize=(7, 7)):
    image = np.array(image, dtype=np.uint8)
    plt.figure()
    plt.axis("off")
    plt.imshow(image)
    return plt

def visualize_images(images, figsize=(7, 7)):
  for image in images:
    visualize_image(image, figsize)

def visualize_detections(
    image, box, label, figsize=(7, 7), linewidth=1, color=[0, 0, 1]
):
    # the function gets as input the image, the bounding box in xmin, ymin, xmax and ymax format and the label as an integer (0 or 1)
    plt = visualize_image(image)
    ax = plt.gca()
    text = "{}:".format(labels[label])
    x1, y1, x2, y2 = box
    w, h = x2 - x1, y2 - y1
    patch = plt.Rectangle(
        [x1, y1], w, h, fill=False, edgecolor=color, linewidth=linewidth
    )
    ax.add_patch(patch)
    ax.text(
        x1,
        y1,
        text,
        bbox={"facecolor": color, "alpha": 0.4},
        clip_box=ax.clipbox,
        clip_on=True,
    )
    plt.show()
    return ax

# %%
def rescale_bbox(image_shape, bbox):
  # bbox is a tensor with the normalized coordinates of the bounding box expressed in xmin, ymin, xmax, ymax format
  # the function denormalizes the coordinates and returns the corresponding tensor
  return tf.stack(
        [
            bbox[0] * image_shape[1],
            bbox[1] * image_shape[0],
            bbox[2] * image_shape[1],
            bbox[3] * image_shape[0]
        ])

# %% [markdown]
# The functions in the next cell are an adaptation of the code used in the [Keras tutorial of RetinaNet](https://keras.io/examples/vision/retinanet/)
#
# The coordinates of the bounding boxes can be expressed in two formats:
# *   xmin, ymin, xmax, ymax (minmax for short)
# *   xcenter, ycenter, width, height (xywh for short)
#
# The two functions below convert a format to the other one and viceversa.
#
# Both are needed because to visualize them we need the first format, while the format used to train the network is the second

# %%
def convert_to_xywh(boxes):
    return tf.concat(
        [(boxes[..., :2] + boxes[..., 2:]) / 2.0, boxes[..., 2:] - boxes[..., :2]],
        axis=-1,
    )

def convert_to_minmax(boxes):
    return tf.concat(
        [boxes[..., :2] - boxes[..., 2:] / 2.0, boxes[..., :2] + boxes[..., 2:] / 2.0],
        axis=-1,
    )

# %%
def flip_horizontal(image, boxes):
    # we flip the image given in input and modify accordingly the bounding boxes, which are here expressed in xywh
    flipped_image = tf.image.flip_left_right(image)
    flipped_boxes = tf.stack(
        [1 - boxes[0], boxes[1], boxes[2], boxes[3]], axis=-1
    )
    return flipped_image, flipped_boxes

# %% [markdown]
# The next function is the function that takes the raw data from the ground truth files and converts it to a format that will be used during the training and test of the network.

# %%
def preprocess_data(sample):
    # sample is a dictionary containing all the relevant information about an image
    # normalize each coordinate on the basis of the original width and height of the image
    normalized_xmin = sample["xmin"] / sample["width"]
    normalized_ymin = sample["ymin"] / sample["height"]
    normalized_xmax = sample["xmax"] / sample["width"]
    normalized_ymax = sample["ymax"] / sample["height"]
    # convert the list of coordinates into a tensor and in xywh format
    bounding_box = [normalized_xmin, normalized_ymin, normalized_xmax, normalized_ymax]
    bboxes = tf.convert_to_tensor(bounding_box)
    bboxes = convert_to_xywh(bboxes)
    label = tf.convert_to_tensor(sample["label"], dtype=tf.float32)
    ground_truth = tf.stack(
        [
            bboxes[0],
            bboxes[1],
            bboxes[2],
            bboxes[3]
        ],
        axis=-1,
    )
    return ground_truth, label

# %% [markdown]
# In the next cell we take each image, we parse the relative annotation file to get the relevant information and we create the dataset

# %%
import os

path = "preprocessed_annotations"
i = 0

annotations = os.listdir(path)
# sorting in lexicographic order is needed to match image ordering
annotations.sort()

list_of_features = []
list_of_bboxes = []
list_of_labels = []

for image in image_dataset:
  
  # get the path of the annotation file corresponding to the image
  file_name = annotations[i]
  file_path = os.path.join(path, file_name)

  sample = {}
  
  with open(file_path, 'r') as f:

    # fill the dictionary with the relevant information
    sample["width"] = int(f.readline())
    sample["height"] = int(f.readline())
    sample["xmin"] = int(f.readline())
    sample["ymin"] = int(f.readline())
    sample["xmax"] = int(f.readline())
    sample["ymax"] = int(f.readline())
    # label is here normalized as a value contained in the set {0, 1}.
    # In the annotation file 1 stands for class "without mask" and 2 stands for class "with mask", here we set 0 as "without mask" and 1 as "with mask"
    sample["label"] = int(f.readline()) - 1
    bounding_box, label = preprocess_data(sample)    
  list_of_features.append(image)
  list_of_bboxes.append(bounding_box)
  list_of_labels.append(label)
  # if the image belongs to class "withouth mask" generate the flipped image to augment the dataset
  if sample["label"] == 0:
    flipped_image, flipped_bbox = flip_horizontal(image, bounding_box)
    list_of_features.append(flipped_image)
    list_of_bboxes.append(flipped_bbox)
    list_of_labels.append(label)
  i = i + 1
  if (i % 200 == 0):
    print(i)

feature_tensor = tf.convert_to_tensor(list_of_features)
bounding_box_tensor = tf.convert_to_tensor(list_of_bboxes)
labels_tensor = tf.convert_to_tensor(list_of_labels)

# set test size
test_set_size = int(np.floor(feature_tensor.shape[0]*0.2))
# Out:
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800

# %%
# shuffle the three tensors in such a way the elements remained coupled across tensors
random_seed = 100
tf.random.set_seed(random_seed)
feature_tensor = tf.random.shuffle(feature_tensor)
tf.random.set_seed(random_seed)
bounding_box_tensor = tf.random.shuffle(bounding_box_tensor)
tf.random.set_seed(random_seed)
labels_tensor = tf.random.shuffle(labels_tensor)

# %%
# verify that each bounding box and each label is still at the same index as the relative image
index = 133
bbox = convert_to_minmax(bounding_box_tensor[index])
scaled_bbox = rescale_bbox(feature_tensor[index].shape, bbox)
visualize_detections(feature_tensor[index], scaled_bbox, int(labels_tensor[index].numpy()))

# %%
# split in training set and test set
feature_test_set = feature_tensor[:test_set_size]
feature_tensor = feature_tensor[test_set_size:]
bounding_box_test_set = bounding_box_tensor[:test_set_size]
bounding_box_tensor = bounding_box_tensor[test_set_size:]
labels_test_set = labels_tensor[:test_set_size]
labels_tensor = labels_tensor[test_set_size:]

# %% [markdown]
# The function in the next cell is an adaptation of the code used in the [Keras tutorial of RetinaNet](https://keras.io/examples/vision/retinanet/)
#
# The function is used as a callback metric during training and test for measuring the performance of the regression head

# %%
def IoU_metric(y_true, y_pred):
    # y_true is a tensor representing the ground truth bounding boxes for a given batch of samples (in format xywh)
    # y_pred is a tensor representing the predicted bounding boxes for the same batch of samples (in format xywh)
    # the function computes the IoU score for each couple (ground truth bounding box, predicted bounding box)
    boxes1_corners = convert_to_minmax(y_true)
    boxes2_corners = convert_to_minmax(y_pred)

    # compute the intersection area
    lu = tf.maximum(boxes1_corners[:, :2], boxes2_corners[:, :2])
    rd = tf.minimum(boxes1_corners[:, 2:], boxes2_corners[:, 2:])
    intersection = tf.maximum(0.0, rd - lu)
    intersection_area = intersection[:, 0] * intersection[:, 1]

    # compute the union area
    boxes1_area = y_true[:, 2] * y_true[:, 3]
    boxes2_area = y_pred[:, 2] * y_pred[:, 3]  
    union_area = tf.maximum(
        boxes1_area + boxes2_area - intersection_area, 1e-8
    )

    # compute IoU
    return tf.clip_by_value(intersection_area / union_area, 0.0, 1.0)

# %%
from tensorflow import keras

# instantiate the model
input = keras.Input(shape=(128,128,3), name="input")
model = keras.layers.Conv2D(16, (3, 3), activation='relu')(input)
model = keras.layers.Conv2D(32, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(64, (3, 3), activation='relu')(model)
model = keras.layers.Conv2D(64, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(128, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(256, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Flatten()(model)
dropout_cls = keras.layers.Dropout(0.8)(model)
dropout_box = keras.layers.Dropout(0.7)(model)
dense_cls = keras.layers.Dense(32, activation='relu')(dropout_cls)
classification_head = keras.layers.Dense(1, activation='sigmoid', name="labels")(dense_cls)
regression_head = keras.layers.Dense(4, activation='sigmoid', name="bounding_box")(dropout_box)

# %%
# define input and outputs of the model
model = keras.Model(
    inputs=input,
    outputs=[classification_head, regression_head],
)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_16 (Conv2D)             (None, 126, 126, 32  896         ['input[0][0]']
#                                 )
#
#  max_pooling2d_16 (MaxPooling2D  (None, 63, 63, 32)  0           ['conv2d_16[0][0]']
#  )
#
#  conv2d_17 (Conv2D)             (None, 61, 61, 64)   18496       ['max_pooling2d_16[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 30, 30, 64)  0           ['conv2d_17[0][0]']
#  )
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 128)  73856       ['max_pooling2d_17[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 14, 14, 128)  0          ['conv2d_18[0][0]']
#  )
#
#  conv2d_19 (Conv2D)             (None, 12, 12, 256)  295168      ['max_pooling2d_18[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 6, 6, 256)   0           ['conv2d_19[0][0]']
#  )
#
#  flatten_4 (Flatten)            (None, 9216)         0           ['max_pooling2d_19[0][0]']
#
#  dropout_8 (Dropout)            (None, 9216)         0           ['flatten_4[0][0]']
#
#  dense_4 (Dense)                (None, 32)           294944      ['dropout_8[0][0]']
#
#  dropout_9 (Dropout)            (None, 9216)         0           ['flatten_4[0][0]']
#
#  labels (Dense)                 (None, 1)            33          ['dense_4[0][0]']
#
#  bounding_box (Dense)           (None, 4)            36868       ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 720,261
# Trainable params: 720,261
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# compile the model
model.compile(
    optimizer=keras.optimizers.RMSprop(0.5e-3),

    # define which loss to use for each head of the network
    loss={
        "bounding_box": keras.losses.MeanSquaredError(),
        "labels": keras.losses.BinaryCrossentropy(),
    },

    # the total loss is a linear combination of the two losses of the network, here we define the weights of each loss
    loss_weights={"labels": 1.0, "bounding_box": 10.0},

    # define which metrics to use for each head of the network, here we select our custom callback function IoU_metric() for the regression head
    metrics={'labels':'accuracy', 'bounding_box': [IoU_metric]}
)

# this is done to implement early stopping
model_dir = "models/"
experiment = "scratch_cnn_exp7.h5"
save_path = os.path.join(model_dir, experiment)

callbacks_list = [
    keras.callbacks.ModelCheckpoint(
      filepath=save_path,
      monitor="val_loss",
      verbose=1,
      save_best_only=True),

    # the ReduceLROnPlateau reduce adaptively the learning rate when the validation loss is not decreasing anymore
    keras.callbacks.ReduceLROnPlateau(verbose=1, patience=2, factor=0.8)
]

# %%
history = model.fit(
              {"input": feature_tensor},
              {"labels": labels_tensor, "bounding_box": bounding_box_tensor},
              epochs = 30,
              batch_size=8,
              validation_split=0.2,
              shuffle=True,
              callbacks = callbacks_list
          )
# Out:
# Epoch 1/30
# 172/172 [==============================] - ETA: 0s - loss: 1.8961 - labels_loss: 1.1604 - bounding_box_loss: 0.0736 - labels_accuracy: 0.7212 - bounding_box_IoU_metric: 0.0524
# Epoch 1: val_loss improved from inf to 0.80026, saving model to models/scratch_cnn_exp8.h5
# 172/172 [==============================] - 56s 316ms/step - loss: 1.8961 - labels_loss: 1.1604 - bounding_box_loss: 0.0736 - labels_accuracy: 0.7212 - bounding_box_IoU_metric: 0.0524 - val_loss: 0.8003 - val_labels_loss: 0.5611 - val_bounding_box_loss: 0.0239 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.0967 - lr: 5.0000e-04
# Epoch 2/30
# 172/172 [==============================] - ETA: 0s - loss: 0.8861 - labels_loss: 0.6191 - bounding_box_loss: 0.0267 - labels_accuracy: 0.7431 - bounding_box_IoU_metric: 0.1140
# Epoch 2: val_loss did not improve from 0.80026
# 172/172 [==============================] - 53s 311ms/step - loss: 0.8861 - labels_loss: 0.6191 - bounding_box_loss: 0.0267 - labels_accuracy: 0.7431 - bounding_box_IoU_metric: 0.1140 - val_loss: 0.8023 - val_labels_loss: 0.5792 - val_bounding_box_loss: 0.0223 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.1096 - lr: 5.0000e-04
# Epoch 3/30
# 172/172 [==============================] - ETA: 0s - loss: 0.8117 - labels_loss: 0.5786 - bounding_box_loss: 0.0233 - labels_accuracy: 0.7423 - bounding_box_IoU_metric: 0.1284
# Epoch 3: val_loss improved from 0.80026 to 0.77786, saving model to models/scratch_cnn_exp8.h5
# 172/172 [==============================] - 53s 311ms/step - loss: 0.8117 - labels_loss: 0.5786 - bounding_box_loss: 0.0233 - labels_accuracy: 0.7423 - bounding_box_IoU_metric: 0.1284 - val_loss: 0.7779 - val_labels_loss: 0.5678 - val_bounding_box_loss: 0.0210 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.1389 - lr: 5.0000e-04
# Epoch 4/30
# 172/172 [==============================] - ETA: 0s - loss: 0.8128 - labels_loss: 0.5907 - bounding_box_loss: 0.0222 - labels_accuracy: 0.7431 - bounding_box_IoU_metric: 0.1390
# Epoch 4: val_loss did not improve from 0.77786
# 172/172 [==============================] - 53s 311ms/step - loss: 0.8128 - labels_loss: 0.5907 - bounding_box_loss: 0.0222 - labels_accuracy: 0.7431 - bounding_box_IoU_metric: 0.1390 - val_loss: 0.7818 - val_labels_loss: 0.5735 - val_bounding_box_loss: 0.0208 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.1291 - lr: 5.0000e-04
# Epoch 5/30
# 172/172 [==============================] - ETA: 0s - loss: 0.7769 - labels_loss: 0.5682 - bounding_box_loss: 0.0209 - labels_accuracy: 0.7431 - bounding_box_IoU_metric: 0.1466
# Epoch 5: val_loss did not improve from 0.77786
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 172/172 [==============================] - 53s 311ms/step - loss: 0.7769 - labels_loss: 0.5682 - bounding_box_loss: 0.0209 - labels_accuracy: 0.7431 - bounding_box_IoU_metric: 0.1466 - val_loss: 1.0526 - val_labels_loss: 0.7579 - val_bounding_box_loss: 0.0295 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.0690 - lr: 5.0000e-04
# Epoch 6/30
# 172/172 [==============================] - ETA: 0s - loss: 0.7440 - labels_loss: 0.5510 - bounding_box_loss: 0.0193 - labels_accuracy: 0.7431 - bounding_box_IoU_metric: 0.1651
# Epoch 6: val_loss improved from 0.77786 to 0.76127, saving model to models/scratch_cnn_exp8.h5
# 172/172 [==============================] - 53s 310ms/step - loss: 0.7440 - labels_loss: 0.5510 - bounding_box_loss: 0.0193 - labels_accuracy: 0.7431 - bounding_box_IoU_metric: 0.1651 - val_loss: 0.7613 - val_labels_loss: 0.5460 - val_bounding_box_loss: 0.0215 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.1134 - lr: 4.0000e-04
# Epoch 7/30
# 172/172 [==============================] - ETA: 0s - loss: 0.7285 - labels_loss: 0.5438 - bounding_box_loss: 0.0185 - labels_accuracy: 0.7438 - bounding_box_IoU_metric: 0.1758
# Epoch 7: val_loss improved from 0.76127 to 0.71421, saving model to models/scratch_cnn_exp8.h5
# 172/172 [==============================] - 53s 311ms/step - loss: 0.7285 - labels_loss: 0.5438 - bounding_box_loss: 0.0185 - labels_accuracy: 0.7438 - bounding_box_IoU_metric: 0.1758 - val_loss: 0.7142 - val_labels_loss: 0.5316 - val_bounding_box_loss: 0.0183 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.1693 - lr: 4.0000e-04
# Epoch 8/30
# 172/172 [==============================] - ETA: 0s - loss: 0.7193 - labels_loss: 0.5380 - bounding_box_loss: 0.0181 - labels_accuracy: 0.7460 - bounding_box_IoU_metric: 0.1669
# Epoch 8: val_loss did not improve from 0.71421
# 172/172 [==============================] - 53s 310ms/step - loss: 0.7193 - labels_loss: 0.5380 - bounding_box_loss: 0.0181 - labels_accuracy: 0.7460 - bounding_box_IoU_metric: 0.1669 - val_loss: 0.7518 - val_labels_loss: 0.5528 - val_bounding_box_loss: 0.0199 - val_labels_accuracy: 0.7580 - val_bounding_box_IoU_metric: 0.1886 - lr: 4.0000e-04
# Epoch 9/30
# 172/172 [==============================] - ETA: 0s - loss: 0.7004 - labels_loss: 0.5257 - bounding_box_loss: 0.0175 - labels_accuracy: 0.7460 - bounding_box_IoU_metric: 0.1885
# Epoch 9: val_loss did not improve from 0.71421
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.00032000001519918444.
# 172/172 [==============================] - 53s 309ms/step - loss: 0.7004 - labels_loss: 0.5257 - bounding_box_loss: 0.0175 - labels_accuracy: 0.7460 - bounding_box_IoU_metric: 0.1885 - val_loss: 0.7321 - val_labels_loss: 0.5296 - val_bounding_box_loss: 0.0203 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.1804 - lr: 4.0000e-04
# Epoch 10/30
# 172/172 [==============================] - ETA: 0s - loss: 0.6753 - labels_loss: 0.5067 - bounding_box_loss: 0.0169 - labels_accuracy: 0.7474 - bounding_box_IoU_metric: 0.1912
# Epoch 10: val_loss improved from 0.71421 to 0.70231, saving model to models/scratch_cnn_exp8.h5
# 172/172 [==============================] - 54s 317ms/step - loss: 0.6753 - labels_loss: 0.5067 - bounding_box_loss: 0.0169 - labels_accuracy: 0.7474 - bounding_box_IoU_metric: 0.1912 - val_loss: 0.7023 - val_labels_loss: 0.5307 - val_bounding_box_loss: 0.0172 - val_labels_accuracy: 0.7493 - val_bounding_box_IoU_metric: 0.1995 - lr: 3.2000e-04
# Epoch 11/30
# 172/172 [==============================] - ETA: 0s - loss: 0.6556 - labels_loss: 0.4979 - bounding_box_loss: 0.0158 - labels_accuracy: 0.7540 - bounding_box_IoU_metric: 0.1997
# Epoch 11: val_loss improved from 0.70231 to 0.67376, saving model to models/scratch_cnn_exp8.h5
# 172/172 [==============================] - 54s 312ms/step - loss: 0.6556 - labels_loss: 0.4979 - bounding_box_loss: 0.0158 - labels_accuracy: 0.7540 - bounding_box_IoU_metric: 0.1997 - val_loss: 0.6738 - val_labels_loss: 0.5033 - val_bounding_box_loss: 0.0170 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.2025 - lr: 3.2000e-04
# Epoch 12/30
# 172/172 [==============================] - ETA: 0s - loss: 0.6568 - labels_loss: 0.5003 - bounding_box_loss: 0.0157 - labels_accuracy: 0.7584 - bounding_box_IoU_metric: 0.1978
# Epoch 12: val_loss improved from 0.67376 to 0.67313, saving model to models/scratch_cnn_exp8.h5
# 172/172 [==============================] - 54s 314ms/step - loss: 0.6568 - labels_loss: 0.5003 - bounding_box_loss: 0.0157 - labels_accuracy: 0.7584 - bounding_box_IoU_metric: 0.1978 - val_loss: 0.6731 - val_labels_loss: 0.4965 - val_bounding_box_loss: 0.0177 - val_labels_accuracy: 0.7493 - val_bounding_box_IoU_metric: 0.2032 - lr: 3.2000e-04
# Epoch 13/30
# 172/172 [==============================] - ETA: 0s - loss: 0.6358 - labels_loss: 0.4826 - bounding_box_loss: 0.0153 - labels_accuracy: 0.7489 - bounding_box_IoU_metric: 0.1985
# Epoch 13: val_loss did not improve from 0.67313
# 172/172 [==============================] - 54s 311ms/step - loss: 0.6358 - labels_loss: 0.4826 - bounding_box_loss: 0.0153 - labels_accuracy: 0.7489 - bounding_box_IoU_metric: 0.1985 - val_loss: 0.7848 - val_labels_loss: 0.6113 - val_bounding_box_loss: 0.0173 - val_labels_accuracy: 0.7493 - val_bounding_box_IoU_metric: 0.1942 - lr: 3.2000e-04
# Epoch 14/30
# 172/172 [==============================] - ETA: 0s - loss: 0.6142 - labels_loss: 0.4663 - bounding_box_loss: 0.0148 - labels_accuracy: 0.7606 - bounding_box_IoU_metric: 0.2030
# Epoch 14: val_loss did not improve from 0.67313
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002560000168159604.
# 172/172 [==============================] - 53s 308ms/step - loss: 0.6142 - labels_loss: 0.4663 - bounding_box_loss: 0.0148 - labels_accuracy: 0.7606 - bounding_box_IoU_metric: 0.2030 - val_loss: 0.6979 - val_labels_loss: 0.5274 - val_bounding_box_loss: 0.0171 - val_labels_accuracy: 0.7551 - val_bounding_box_IoU_metric: 0.2193 - lr: 3.2000e-04
# Epoch 15/30
# 172/172 [==============================] - ETA: 0s - loss: 0.5996 - labels_loss: 0.4517 - bounding_box_loss: 0.0148 - labels_accuracy: 0.7686 - bounding_box_IoU_metric: 0.2117
# Epoch 15: val_loss did not improve from 0.67313
# 172/172 [==============================] - 53s 310ms/step - loss: 0.5996 - labels_loss: 0.4517 - bounding_box_loss: 0.0148 - labels_accuracy: 0.7686 - bounding_box_IoU_metric: 0.2117 - val_loss: 0.7032 - val_labels_loss: 0.5401 - val_bounding_box_loss: 0.0163 - val_labels_accuracy: 0.7464 - val_bounding_box_IoU_metric: 0.1826 - lr: 2.5600e-04
# Epoch 16/30
# 172/172 [==============================] - ETA: 0s - loss: 0.5788 - labels_loss: 0.4358 - bounding_box_loss: 0.0143 - labels_accuracy: 0.7781 - bounding_box_IoU_metric: 0.2119
# Epoch 16: val_loss did not improve from 0.67313
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00020480002276599408.
# 172/172 [==============================] - 53s 310ms/step - loss: 0.5788 - labels_loss: 0.4358 - bounding_box_loss: 0.0143 - labels_accuracy: 0.7781 - bounding_box_IoU_metric: 0.2119 - val_loss: 0.7303 - val_labels_loss: 0.5749 - val_bounding_box_loss: 0.0155 - val_labels_accuracy: 0.7493 - val_bounding_box_IoU_metric: 0.1986 - lr: 2.5600e-04
# Epoch 17/30
# 172/172 [==============================] - ETA: 0s - loss: 0.5641 - labels_loss: 0.4255 - bounding_box_loss: 0.0139 - labels_accuracy: 0.7847 - bounding_box_IoU_metric: 0.2108
# Epoch 17: val_loss did not improve from 0.67313
# 172/172 [==============================] - 53s 311ms/step - loss: 0.5641 - labels_loss: 0.4255 - bounding_box_loss: 0.0139 - labels_accuracy: 0.7847 - bounding_box_IoU_metric: 0.2108 - val_loss: 0.7850 - val_labels_loss: 0.6322 - val_bounding_box_loss: 0.0153 - val_labels_accuracy: 0.7493 - val_bounding_box_IoU_metric: 0.2019 - lr: 2.0480e-04
# Epoch 18/30
# 172/172 [==============================] - ETA: 0s - loss: 0.5505 - labels_loss: 0.4154 - bounding_box_loss: 0.0135 - labels_accuracy: 0.7847 - bounding_box_IoU_metric: 0.2193
# Epoch 18: val_loss did not improve from 0.67313
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00016384001355618238.
# 172/172 [==============================] - 53s 309ms/step - loss: 0.5505 - labels_loss: 0.4154 - bounding_box_loss: 0.0135 - labels_accuracy: 0.7847 - bounding_box_IoU_metric: 0.2193 - val_loss: 0.7863 - val_labels_loss: 0.6322 - val_bounding_box_loss: 0.0154 - val_labels_accuracy: 0.7493 - val_bounding_box_IoU_metric: 0.2077 - lr: 2.0480e-04
# Epoch 19/30
# 172/172 [==============================] - ETA: 0s - loss: 0.5291 - labels_loss: 0.3983 - bounding_box_loss: 0.0131 - labels_accuracy: 0.7993 - bounding_box_IoU_metric: 0.2165
# Epoch 19: val_loss did not improve from 0.67313
# 172/172 [==============================] - 53s 311ms/step - loss: 0.5291 - labels_loss: 0.3983 - bounding_box_loss: 0.0131 - labels_accuracy: 0.7993 - bounding_box_IoU_metric: 0.2165 - val_loss: 0.7089 - val_labels_loss: 0.5545 - val_bounding_box_loss: 0.0154 - val_labels_accuracy: 0.7784 - val_bounding_box_IoU_metric: 0.2207 - lr: 1.6384e-04
# Epoch 20/30
# 172/172 [==============================] - ETA: 0s - loss: 0.5140 - labels_loss: 0.3784 - bounding_box_loss: 0.0136 - labels_accuracy: 0.8088 - bounding_box_IoU_metric: 0.2161
# Epoch 20: val_loss did not improve from 0.67313
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001310720108449459.
# 172/172 [==============================] - 53s 308ms/step - loss: 0.5140 - labels_loss: 0.3784 - bounding_box_loss: 0.0136 - labels_accuracy: 0.8088 - bounding_box_IoU_metric: 0.2161 - val_loss: 0.7408 - val_labels_loss: 0.5820 - val_bounding_box_loss: 0.0159 - val_labels_accuracy: 0.7697 - val_bounding_box_IoU_metric: 0.1912 - lr: 1.6384e-04
# Epoch 21/30
# 172/172 [==============================] - ETA: 0s - loss: 0.4966 - labels_loss: 0.3653 - bounding_box_loss: 0.0131 - labels_accuracy: 0.8204 - bounding_box_IoU_metric: 0.2217
# Epoch 21: val_loss did not improve from 0.67313
# 172/172 [==============================] - 54s 311ms/step - loss: 0.4966 - labels_loss: 0.3653 - bounding_box_loss: 0.0131 - labels_accuracy: 0.8204 - bounding_box_IoU_metric: 0.2217 - val_loss: 0.7078 - val_labels_loss: 0.5596 - val_bounding_box_loss: 0.0148 - val_labels_accuracy: 0.7755 - val_bounding_box_IoU_metric: 0.1965 - lr: 1.3107e-04
# Epoch 22/30
# 172/172 [==============================] - ETA: 0s - loss: 0.4829 - labels_loss: 0.3565 - bounding_box_loss: 0.0126 - labels_accuracy: 0.8321 - bounding_box_IoU_metric: 0.2215
# Epoch 22: val_loss did not improve from 0.67313
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00010485760867595673.
# 172/172 [==============================] - 53s 310ms/step - loss: 0.4829 - labels_loss: 0.3565 - bounding_box_loss: 0.0126 - labels_accuracy: 0.8321 - bounding_box_IoU_metric: 0.2215 - val_loss: 0.7358 - val_labels_loss: 0.5824 - val_bounding_box_loss: 0.0153 - val_labels_accuracy: 0.7813 - val_bounding_box_IoU_metric: 0.1888 - lr: 1.3107e-04
# Epoch 23/30
# 172/172 [==============================] - ETA: 0s - loss: 0.4527 - labels_loss: 0.3260 - bounding_box_loss: 0.0127 - labels_accuracy: 0.8489 - bounding_box_IoU_metric: 0.2196
# Epoch 23: val_loss did not improve from 0.67313
# 172/172 [==============================] - 53s 310ms/step - loss: 0.4527 - labels_loss: 0.3260 - bounding_box_loss: 0.0127 - labels_accuracy: 0.8489 - bounding_box_IoU_metric: 0.2196 - val_loss: 0.7535 - val_labels_loss: 0.6087 - val_bounding_box_loss: 0.0145 - val_labels_accuracy: 0.7843 - val_bounding_box_IoU_metric: 0.2111 - lr: 1.0486e-04
# Epoch 24/30
# 172/172 [==============================] - ETA: 0s - loss: 0.4604 - labels_loss: 0.3343 - bounding_box_loss: 0.0126 - labels_accuracy: 0.8409 - bounding_box_IoU_metric: 0.2246
# Epoch 24: val_loss did not improve from 0.67313
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 8.388608694076538e-05.
# 172/172 [==============================] - 53s 309ms/step - loss: 0.4604 - labels_loss: 0.3343 - bounding_box_loss: 0.0126 - labels_accuracy: 0.8409 - bounding_box_IoU_metric: 0.2246 - val_loss: 0.7920 - val_labels_loss: 0.6389 - val_bounding_box_loss: 0.0153 - val_labels_accuracy: 0.7930 - val_bounding_box_IoU_metric: 0.2065 - lr: 1.0486e-04
# Epoch 25/30
# 172/172 [==============================] - ETA: 0s - loss: 0.4311 - labels_loss: 0.3112 - bounding_box_loss: 0.0120 - labels_accuracy: 0.8584 - bounding_box_IoU_metric: 0.2298
# Epoch 25: val_loss did not improve from 0.67313
# 172/172 [==============================] - 53s 310ms/step - loss: 0.4311 - labels_loss: 0.3112 - bounding_box_loss: 0.0120 - labels_accuracy: 0.8584 - bounding_box_IoU_metric: 0.2298 - val_loss: 0.7178 - val_labels_loss: 0.5740 - val_bounding_box_loss: 0.0144 - val_labels_accuracy: 0.7755 - val_bounding_box_IoU_metric: 0.2093 - lr: 8.3886e-05
# Epoch 26/30
# 172/172 [==============================] - ETA: 0s - loss: 0.4223 - labels_loss: 0.3004 - bounding_box_loss: 0.0122 - labels_accuracy: 0.8547 - bounding_box_IoU_metric: 0.2292
# Epoch 26: val_loss did not improve from 0.67313
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.710886955261231e-05.
# 172/172 [==============================] - 53s 308ms/step - loss: 0.4223 - labels_loss: 0.3004 - bounding_box_loss: 0.0122 - labels_accuracy: 0.8547 - bounding_box_IoU_metric: 0.2292 - val_loss: 0.8523 - val_labels_loss: 0.6985 - val_bounding_box_loss: 0.0154 - val_labels_accuracy: 0.7959 - val_bounding_box_IoU_metric: 0.1873 - lr: 8.3886e-05
# Epoch 27/30
# 172/172 [==============================] - ETA: 0s - loss: 0.4068 - labels_loss: 0.2854 - bounding_box_loss: 0.0121 - labels_accuracy: 0.8774 - bounding_box_IoU_metric: 0.2217
# Epoch 27: val_loss improved from 0.67313 to 0.65408, saving model to models/scratch_cnn_exp8.h5
# 172/172 [==============================] - 53s 310ms/step - loss: 0.4068 - labels_loss: 0.2854 - bounding_box_loss: 0.0121 - labels_accuracy: 0.8774 - bounding_box_IoU_metric: 0.2217 - val_loss: 0.6541 - val_labels_loss: 0.5052 - val_bounding_box_loss: 0.0149 - val_labels_accuracy: 0.8076 - val_bounding_box_IoU_metric: 0.1991 - lr: 6.7109e-05
# Epoch 28/30
# 172/172 [==============================] - ETA: 0s - loss: 0.3937 - labels_loss: 0.2750 - bounding_box_loss: 0.0119 - labels_accuracy: 0.8788 - bounding_box_IoU_metric: 0.2267
# Epoch 28: val_loss did not improve from 0.65408
# 172/172 [==============================] - 53s 310ms/step - loss: 0.3937 - labels_loss: 0.2750 - bounding_box_loss: 0.0119 - labels_accuracy: 0.8788 - bounding_box_IoU_metric: 0.2267 - val_loss: 0.7466 - val_labels_loss: 0.6039 - val_bounding_box_loss: 0.0143 - val_labels_accuracy: 0.8047 - val_bounding_box_IoU_metric: 0.2061 - lr: 6.7109e-05
# Epoch 29/30
# 172/172 [==============================] - ETA: 0s - loss: 0.3937 - labels_loss: 0.2745 - bounding_box_loss: 0.0119 - labels_accuracy: 0.8752 - bounding_box_IoU_metric: 0.2300
# Epoch 29: val_loss did not improve from 0.65408
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 5.3687096806243065e-05.
# 172/172 [==============================] - 53s 311ms/step - loss: 0.3937 - labels_loss: 0.2745 - bounding_box_loss: 0.0119 - labels_accuracy: 0.8752 - bounding_box_IoU_metric: 0.2300 - val_loss: 0.7927 - val_labels_loss: 0.6496 - val_bounding_box_loss: 0.0143 - val_labels_accuracy: 0.8076 - val_bounding_box_IoU_metric: 0.2119 - lr: 6.7109e-05
# Epoch 30/30
# 172/172 [==============================] - ETA: 0s - loss: 0.3836 - labels_loss: 0.2650 - bounding_box_loss: 0.0119 - labels_accuracy: 0.8818 - bounding_box_IoU_metric: 0.2318
# Epoch 30: val_loss did not improve from 0.65408
# 172/172 [==============================] - 53s 310ms/step - loss: 0.3836 - labels_loss: 0.2650 - bounding_box_loss: 0.0119 - labels_accuracy: 0.8818 - bounding_box_IoU_metric: 0.2318 - val_loss: 0.7913 - val_labels_loss: 0.6489 - val_bounding_box_loss: 0.0142 - val_labels_accuracy: 0.7988 - val_bounding_box_IoU_metric: 0.2090 - lr: 5.3687e-05

# %%
#plot the history of the training

plt.figure(figsize=(12,5))
plt.title('labels loss')
plt.plot(history.history['labels_loss'],'bo-',label = 'train_labels_loss')
plt.plot(history.history['val_labels_loss'],'b-',label = 'val_labels_loss')
plt.ylim(0,1)
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('bbox loss')
plt.plot(history.history['bounding_box_loss'],'bo-',label = 'train_bounding_box_loss')
plt.plot(history.history['val_bounding_box_loss'],'b-',label = 'val_bounding_box_loss')
plt.ylim(0,0.04)
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('total loss')
plt.plot(history.history['loss'],'bo-',label = 'train_loss')
plt.plot(history.history['val_loss'],'b-',label = 'val_loss')
plt.ylim(0,2)
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('accuracy')
plt.plot(history.history['labels_accuracy'],'bo-',label = 'train_labels_accuracy')
plt.plot(history.history['val_labels_accuracy'],'b-',label = 'val_labels_accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('IoU scaled in [0,1]')
plt.plot(history.history['bounding_box_IoU_metric'],'bo-',label = 'train_bounding_box_IoU_metric')
plt.plot(history.history['val_bounding_box_IoU_metric'],'b-',label = 'val_bounding_box_IoU_metric')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model

# delete the current model
del model

# load the model saved by the early stopping callback
model = load_model(os.path.join(model_dir, experiment), custom_objects={"IoU_metric": IoU_metric})

#evaluate the model on the test set
model.evaluate({"input": feature_test_set},
               {"labels": labels_test_set, "bounding_box": bounding_box_test_set}, 
               return_dict=True)
# Out:
# 14/14 [==============================] - 4s 283ms/step - loss: 0.6105 - labels_loss: 0.4677 - bounding_box_loss: 0.0143 - labels_accuracy: 0.7944 - bounding_box_IoU_metric: 0.2005
# {'loss': 0.6105310916900635,
#  'labels_loss': 0.46771422028541565,
#  'bounding_box_loss': 0.014281686395406723,
#  'labels_accuracy': 0.7943925261497498,
#  'bounding_box_IoU_metric': 0.20053638517856598}

# %%
# show actual predictions made by the model on some images of the test set
results = model(feature_test_set[100:120])
labels_list = []
for i in range(20):
  label = tf.cast(tf.round(results[0][i]), dtype=tf.int32)
  bbox = convert_to_minmax(results[1][i])
  scaled_bbox = rescale_bbox(feature_test_set[100+i].shape, bbox)
  visualize_detections(feature_test_set[100 + i], scaled_bbox, label[0].numpy())

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# create and plot the confusion matrix
predictions = model(feature_test_set)
result = confusion_matrix(labels_test_set, tf.cast(tf.math.round(predictions[0]), dtype=tf.int32), normalize='pred')
disp = ConfusionMatrixDisplay(confusion_matrix=result, display_labels=['without mask', 'with mask'])
disp.plot()
plt.show()

# %%
# save the model to google drive
# !cp ./models/scratch_cnn_exp7.h5 /content/drive/MyDrive/CIDL_Project/models/

# %%
# verify that the model was uploaded to drive
drive_dir_model = "/content/drive/MyDrive/CIDL_Project/models/"
experiment = "scratch_cnn_exp7.h5"
model = load_model(os.path.join(drive_dir_model, experiment), custom_objects={"IoU_metric": IoU_metric})
model.evaluate({"input": feature_test_set},
               {"labels": labels_test_set, "bounding_box": bounding_box_test_set}, 
               return_dict=True)
# Out:
# 14/14 [==============================] - 5s 306ms/step - loss: 0.6105 - labels_loss: 0.4677 - bounding_box_loss: 0.0143 - labels_accuracy: 0.7944 - bounding_box_IoU_metric: 0.2005
# {'loss': 0.6105310916900635,
#  'labels_loss': 0.46771422028541565,
#  'bounding_box_loss': 0.014281686395406723,
#  'labels_accuracy': 0.7943925261497498,
#  'bounding_box_IoU_metric': 0.20053638517856598}
