# %% [markdown]
# # Experiment 5

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# download the dataset content from google drive to google colab vm (this is done for efficiency reasons)
# !cp -r /content/drive/MyDrive/CIDL_Project/dataset/preprocessed_annotations/preprocessed_annotations .
# !cp -r /content/drive/MyDrive/CIDL_Project/dataset/preprocessed_images/preprocessed_images .

# %%
import tensorflow as tf

# store the images using a keras utility
image_dataset = tf.keras.utils.image_dataset_from_directory(
    directory='./preprocessed_images',
    labels = None,
    label_mode=None,
    batch_size=None,
    color_mode='rgb',
    # specify the size of the images, all the images are rescaled to this size
    image_size=(128, 128),
    shuffle=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 1861 files belonging to 1 classes.

# %% [markdown]
# The functions in the next cell are an adaptation of the code used in the [Keras tutorial of RetinaNet](https://keras.io/examples/vision/retinanet/)

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ["without mask", "with mask"]

def visualize_image(image, figsize=(7, 7)):
    image = np.array(image, dtype=np.uint8)
    plt.figure()
    plt.axis("off")
    plt.imshow(image)
    return plt

def visualize_images(images, figsize=(7, 7)):
  for image in images:
    visualize_image(image, figsize)

def visualize_detections(
    image, box, label, figsize=(7, 7), linewidth=1, color=[0, 0, 1]
):
    # the function gets as input the image, the bounding box in xmin, ymin, xmax and ymax format and the label as an integer (0 or 1)
    plt = visualize_image(image)
    ax = plt.gca()
    text = "{}:".format(labels[label])
    x1, y1, x2, y2 = box
    w, h = x2 - x1, y2 - y1
    patch = plt.Rectangle(
        [x1, y1], w, h, fill=False, edgecolor=color, linewidth=linewidth
    )
    ax.add_patch(patch)
    ax.text(
        x1,
        y1,
        text,
        bbox={"facecolor": color, "alpha": 0.4},
        clip_box=ax.clipbox,
        clip_on=True,
    )
    plt.show()
    return ax

# %%
def rescale_bbox(image_shape, bbox):
  # bbox is a tensor with the normalized coordinates of the bounding box expressed in xmin, ymin, xmax, ymax format
  # the function denormalizes the coordinates and returns the corresponding tensor
  return tf.stack(
        [
            bbox[0] * image_shape[1],
            bbox[1] * image_shape[0],
            bbox[2] * image_shape[1],
            bbox[3] * image_shape[0]
        ])

# %% [markdown]
# The functions in the next cell are an adaptation of the code used in the [Keras tutorial of RetinaNet](https://keras.io/examples/vision/retinanet/)
#
# The coordinates of the bounding boxes can be expressed in two formats:
# *   xmin, ymin, xmax, ymax (minmax for short)
# *   xcenter, ycenter, width, height (xywh for short)
#
# The two functions below convert a format to the other one and viceversa.
#
# Both are needed because to visualize them we need the first format, while the format used to train the network is the second

# %%
def convert_to_xywh(boxes):
    return tf.concat(
        [(boxes[..., :2] + boxes[..., 2:]) / 2.0, boxes[..., 2:] - boxes[..., :2]],
        axis=-1,
    )

def convert_to_minmax(boxes):
    return tf.concat(
        [boxes[..., :2] - boxes[..., 2:] / 2.0, boxes[..., :2] + boxes[..., 2:] / 2.0],
        axis=-1,
    )

# %%
def flip_horizontal(image, boxes):
    # we flip the image given in input and modify accordingly the bounding boxes, which are here expressed in xywh
    flipped_image = tf.image.flip_left_right(image)
    flipped_boxes = tf.stack(
        [1 - boxes[0], boxes[1], boxes[2], boxes[3]], axis=-1
    )
    return flipped_image, flipped_boxes

# %% [markdown]
# The next function is the function that takes the raw data from the ground truth files and converts it to a format that will be used during the training and test of the network.

# %%
def preprocess_data(sample):
    # sample is a dictionary containing all the relevant information about an image
    # normalize each coordinate on the basis of the original width and height of the image
    normalized_xmin = sample["xmin"] / sample["width"]
    normalized_ymin = sample["ymin"] / sample["height"]
    normalized_xmax = sample["xmax"] / sample["width"]
    normalized_ymax = sample["ymax"] / sample["height"]
    # convert the list of coordinates into a tensor and in xywh format
    bounding_box = [normalized_xmin, normalized_ymin, normalized_xmax, normalized_ymax]
    bboxes = tf.convert_to_tensor(bounding_box)
    bboxes = convert_to_xywh(bboxes)
    label = tf.convert_to_tensor(sample["label"], dtype=tf.float32)
    ground_truth = tf.stack(
        [
            bboxes[0],
            bboxes[1],
            bboxes[2],
            bboxes[3]
        ],
        axis=-1,
    )
    return ground_truth, label

# %% [markdown]
# In the next cell we take each image, we parse the relative annotation file to get the relevant information and we create the dataset

# %%
import os

path = "preprocessed_annotations"
i = 0

annotations = os.listdir(path)
# sorting in lexicographic order is needed to match image ordering
annotations.sort()

list_of_features = []
list_of_bboxes = []
list_of_labels = []

for image in image_dataset:

  # get the path of the annotation file corresponding to the image  
  file_name = annotations[i]
  file_path = os.path.join(path, file_name)

  sample = {}
  
  with open(file_path, 'r') as f:

    # fill the dictionary with the relevant information
    sample["width"] = int(f.readline())
    sample["height"] = int(f.readline())
    sample["xmin"] = int(f.readline())
    sample["ymin"] = int(f.readline())
    sample["xmax"] = int(f.readline())
    sample["ymax"] = int(f.readline())
    # label is here normalized as a value contained in the set {0, 1}.
    # In the annotation file 1 stands for class "without mask" and 2 stands for class "with mask", here we set 0 as "without mask" and 1 as "with mask"
    sample["label"] = int(f.readline()) - 1
    bounding_box, label = preprocess_data(sample)    
  list_of_features.append(image)
  list_of_bboxes.append(bounding_box)
  list_of_labels.append(label)
  # if the image belongs to class "withouth mask" generate the flipped image to augment the dataset
  if sample["label"] == 0:
    flipped_image, flipped_bbox = flip_horizontal(image, bounding_box)
    list_of_features.append(flipped_image)
    list_of_bboxes.append(flipped_bbox)
    list_of_labels.append(label)
  i = i + 1
  if (i % 200 == 0):
    print(i)

feature_tensor = tf.convert_to_tensor(list_of_features)
bounding_box_tensor = tf.convert_to_tensor(list_of_bboxes)
labels_tensor = tf.convert_to_tensor(list_of_labels)

# set test size
test_set_size = int(np.floor(feature_tensor.shape[0]*0.2))
# Out:
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800

# %%
# shuffle the three tensors in such a way the elements remained coupled across tensors
random_seed = 100
tf.random.set_seed(random_seed)
feature_tensor = tf.random.shuffle(feature_tensor)
tf.random.set_seed(random_seed)
bounding_box_tensor = tf.random.shuffle(bounding_box_tensor)
tf.random.set_seed(random_seed)
labels_tensor = tf.random.shuffle(labels_tensor)

# %%
# verify that each bounding box and each label is still at the same index as the relative image
index = 290
bbox = convert_to_minmax(bounding_box_tensor[index])
scaled_bbox = rescale_bbox(feature_tensor[index].shape, bbox)
visualize_detections(feature_tensor[index], scaled_bbox, int(labels_tensor[index].numpy()))

# %%
# split in training set and test set
feature_test_set = feature_tensor[:test_set_size]
feature_tensor = feature_tensor[test_set_size:]
bounding_box_test_set = bounding_box_tensor[:test_set_size]
bounding_box_tensor = bounding_box_tensor[test_set_size:]
labels_test_set = labels_tensor[:test_set_size]
labels_tensor = labels_tensor[test_set_size:]

# %% [markdown]
# The function in the next cell is an adaptation of the code used in the [Keras tutorial of RetinaNet](https://keras.io/examples/vision/retinanet/)
#
# The function is used as a callback metric during training and test for measuring the performance of the regression head

# %%
def IoU_metric(y_true, y_pred):
    # y_true is a tensor representing the ground truth bounding boxes for a given batch of samples (in format xywh)
    # y_pred is a tensor representing the predicted bounding boxes for the same batch of samples (in format xywh)
    # the function computes the IoU score for each couple (ground truth bounding box, predicted bounding box)
    boxes1_corners = convert_to_minmax(y_true)
    boxes2_corners = convert_to_minmax(y_pred)

    # compute the intersection area
    lu = tf.maximum(boxes1_corners[:, :2], boxes2_corners[:, :2])
    rd = tf.minimum(boxes1_corners[:, 2:], boxes2_corners[:, 2:])
    intersection = tf.maximum(0.0, rd - lu)
    intersection_area = intersection[:, 0] * intersection[:, 1]

    # compute the union area
    boxes1_area = y_true[:, 2] * y_true[:, 3]
    boxes2_area = y_pred[:, 2] * y_pred[:, 3]  
    union_area = tf.maximum(
        boxes1_area + boxes2_area - intersection_area, 1e-8
    )

    # compute IoU
    return tf.clip_by_value(intersection_area / union_area, 0.0, 1.0)

# %%
from tensorflow import keras

# instantiate the model
input = keras.Input(shape=(128,128,3), name="input")
model = keras.layers.Conv2D(32, (3, 3), activation='relu')(input)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(64, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(128, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(256, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Flatten()(model)
dropout_cls = keras.layers.Dropout(0.8)(model)
dropout_box = keras.layers.Dropout(0.5)(model)
classification_head = keras.layers.Dense(1, activation='sigmoid', name="labels")(dropout_cls)
regression_head = keras.layers.Dense(4, activation='sigmoid', name="bounding_box")(dropout_box)

# %%
# define input and outputs of the model
model = keras.Model(
    inputs=input,
    outputs=[classification_head, regression_head],
)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 126, 126, 32  896         ['input[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 63, 63, 32)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 61, 61, 64)   18496       ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 30, 30, 64)  0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 128)  0          ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 12, 12, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 256)   0           ['conv2d_3[0][0]']
#
#  flatten (Flatten)              (None, 9216)         0           ['max_pooling2d_3[0][0]']
#
#  dropout (Dropout)              (None, 9216)         0           ['flatten[0][0]']
#
#  dropout_1 (Dropout)            (None, 9216)         0           ['flatten[0][0]']
#
#  labels (Dense)                 (None, 1)            9217        ['dropout[0][0]']
#
#  bounding_box (Dense)           (None, 4)            36868       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 434,501
# Trainable params: 434,501
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# compile the model
model.compile(
    optimizer=keras.optimizers.RMSprop(1e-3),

    # define which loss to use for each head of the network
    loss={
        "bounding_box": keras.losses.MeanSquaredError(),
        "labels": keras.losses.BinaryCrossentropy(),
    },

    # the total loss is a linear combination of the two losses of the network, here we define the weights of each loss
    loss_weights={"labels": 1.0, "bounding_box": 10.0},

    # define which metrics to use for each head of the network, here we select our custom callback function IoU_metric() for the regression head
    metrics={'labels':'accuracy', 'bounding_box': [IoU_metric]}
)

# this is done to implement early stopping
model_dir = "models/"
experiment = "scratch_cnn_exp5.h5"
save_path = os.path.join(model_dir, experiment)

callbacks_list = [
    keras.callbacks.ModelCheckpoint(
      filepath=save_path,
      # we save the model with the lowest validation total loss
      monitor="val_loss",
      verbose=1,
      save_best_only=True),
    
    # the ReduceLROnPlateau reduce adaptively the learning rate when the validation loss is not decreasing anymore
    keras.callbacks.ReduceLROnPlateau(verbose=1, patience=3, factor=0.2)
]

# %%
history = model.fit(
              {"input": feature_tensor},
              {"labels": labels_tensor, "bounding_box": bounding_box_tensor},
              epochs = 20,
              batch_size=32,
              validation_split=0.2,
              shuffle=True,
              callbacks = callbacks_list
          )
# Out:
# Epoch 1/20
# 43/43 [==============================] - ETA: 0s - loss: 4.1364 - labels_loss: 3.4197 - bounding_box_loss: 0.0717 - labels_accuracy: 0.7168 - bounding_box_IoU_metric: 0.0655
# Epoch 1: val_loss improved from inf to 0.99225, saving model to models/scratch_cnn_exp5.h5
# 43/43 [==============================] - 51s 1s/step - loss: 4.1364 - labels_loss: 3.4197 - bounding_box_loss: 0.0717 - labels_accuracy: 0.7168 - bounding_box_IoU_metric: 0.0655 - val_loss: 0.9922 - val_labels_loss: 0.6618 - val_bounding_box_loss: 0.0330 - val_labels_accuracy: 0.7230 - val_bounding_box_IoU_metric: 0.0458 - lr: 0.0010
# Epoch 2/20
# 43/43 [==============================] - ETA: 0s - loss: 0.9915 - labels_loss: 0.6038 - bounding_box_loss: 0.0388 - labels_accuracy: 0.7365 - bounding_box_IoU_metric: 0.0871
# Epoch 2: val_loss improved from 0.99225 to 0.80216, saving model to models/scratch_cnn_exp5.h5
# 43/43 [==============================] - 52s 1s/step - loss: 0.9915 - labels_loss: 0.6038 - bounding_box_loss: 0.0388 - labels_accuracy: 0.7365 - bounding_box_IoU_metric: 0.0871 - val_loss: 0.8022 - val_labels_loss: 0.5816 - val_bounding_box_loss: 0.0221 - val_labels_accuracy: 0.7230 - val_bounding_box_IoU_metric: 0.1272 - lr: 0.0010
# Epoch 3/20
# 43/43 [==============================] - ETA: 0s - loss: 0.8388 - labels_loss: 0.5601 - bounding_box_loss: 0.0279 - labels_accuracy: 0.7453 - bounding_box_IoU_metric: 0.1093
# Epoch 3: val_loss improved from 0.80216 to 0.78923, saving model to models/scratch_cnn_exp5.h5
# 43/43 [==============================] - 47s 1s/step - loss: 0.8388 - labels_loss: 0.5601 - bounding_box_loss: 0.0279 - labels_accuracy: 0.7453 - bounding_box_IoU_metric: 0.1093 - val_loss: 0.7892 - val_labels_loss: 0.5752 - val_bounding_box_loss: 0.0214 - val_labels_accuracy: 0.7230 - val_bounding_box_IoU_metric: 0.1156 - lr: 0.0010
# Epoch 4/20
# 43/43 [==============================] - ETA: 0s - loss: 0.8094 - labels_loss: 0.5585 - bounding_box_loss: 0.0251 - labels_accuracy: 0.7496 - bounding_box_IoU_metric: 0.1303
# Epoch 4: val_loss did not improve from 0.78923
# 43/43 [==============================] - 48s 1s/step - loss: 0.8094 - labels_loss: 0.5585 - bounding_box_loss: 0.0251 - labels_accuracy: 0.7496 - bounding_box_IoU_metric: 0.1303 - val_loss: 0.9681 - val_labels_loss: 0.6650 - val_bounding_box_loss: 0.0303 - val_labels_accuracy: 0.7230 - val_bounding_box_IoU_metric: 0.0563 - lr: 0.0010
# Epoch 5/20
# 43/43 [==============================] - ETA: 0s - loss: 0.7770 - labels_loss: 0.5443 - bounding_box_loss: 0.0233 - labels_accuracy: 0.7460 - bounding_box_IoU_metric: 0.1308
# Epoch 5: val_loss improved from 0.78923 to 0.75307, saving model to models/scratch_cnn_exp5.h5
# 43/43 [==============================] - 50s 1s/step - loss: 0.7770 - labels_loss: 0.5443 - bounding_box_loss: 0.0233 - labels_accuracy: 0.7460 - bounding_box_IoU_metric: 0.1308 - val_loss: 0.7531 - val_labels_loss: 0.5626 - val_bounding_box_loss: 0.0191 - val_labels_accuracy: 0.7230 - val_bounding_box_IoU_metric: 0.1430 - lr: 0.0010
# Epoch 6/20
# 43/43 [==============================] - ETA: 0s - loss: 0.7326 - labels_loss: 0.5325 - bounding_box_loss: 0.0200 - labels_accuracy: 0.7547 - bounding_box_IoU_metric: 0.1610
# Epoch 6: val_loss did not improve from 0.75307
# 43/43 [==============================] - 48s 1s/step - loss: 0.7326 - labels_loss: 0.5325 - bounding_box_loss: 0.0200 - labels_accuracy: 0.7547 - bounding_box_IoU_metric: 0.1610 - val_loss: 0.8040 - val_labels_loss: 0.5804 - val_bounding_box_loss: 0.0224 - val_labels_accuracy: 0.7230 - val_bounding_box_IoU_metric: 0.1756 - lr: 0.0010
# Epoch 7/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6978 - labels_loss: 0.5043 - bounding_box_loss: 0.0194 - labels_accuracy: 0.7657 - bounding_box_IoU_metric: 0.1603
# Epoch 7: val_loss improved from 0.75307 to 0.73263, saving model to models/scratch_cnn_exp5.h5
# 43/43 [==============================] - 47s 1s/step - loss: 0.6978 - labels_loss: 0.5043 - bounding_box_loss: 0.0194 - labels_accuracy: 0.7657 - bounding_box_IoU_metric: 0.1603 - val_loss: 0.7326 - val_labels_loss: 0.5580 - val_bounding_box_loss: 0.0175 - val_labels_accuracy: 0.7201 - val_bounding_box_IoU_metric: 0.1756 - lr: 0.0010
# Epoch 8/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6857 - labels_loss: 0.5066 - bounding_box_loss: 0.0179 - labels_accuracy: 0.7584 - bounding_box_IoU_metric: 0.1734
# Epoch 8: val_loss did not improve from 0.73263
# 43/43 [==============================] - 48s 1s/step - loss: 0.6857 - labels_loss: 0.5066 - bounding_box_loss: 0.0179 - labels_accuracy: 0.7584 - bounding_box_IoU_metric: 0.1734 - val_loss: 0.7391 - val_labels_loss: 0.5480 - val_bounding_box_loss: 0.0191 - val_labels_accuracy: 0.7230 - val_bounding_box_IoU_metric: 0.1575 - lr: 0.0010
# Epoch 9/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6612 - labels_loss: 0.4860 - bounding_box_loss: 0.0175 - labels_accuracy: 0.7650 - bounding_box_IoU_metric: 0.1790
# Epoch 9: val_loss improved from 0.73263 to 0.72242, saving model to models/scratch_cnn_exp5.h5
# 43/43 [==============================] - 52s 1s/step - loss: 0.6612 - labels_loss: 0.4860 - bounding_box_loss: 0.0175 - labels_accuracy: 0.7650 - bounding_box_IoU_metric: 0.1790 - val_loss: 0.7224 - val_labels_loss: 0.5483 - val_bounding_box_loss: 0.0174 - val_labels_accuracy: 0.7201 - val_bounding_box_IoU_metric: 0.1780 - lr: 0.0010
# Epoch 10/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6461 - labels_loss: 0.4752 - bounding_box_loss: 0.0171 - labels_accuracy: 0.7672 - bounding_box_IoU_metric: 0.1749
# Epoch 10: val_loss did not improve from 0.72242
# 43/43 [==============================] - 48s 1s/step - loss: 0.6461 - labels_loss: 0.4752 - bounding_box_loss: 0.0171 - labels_accuracy: 0.7672 - bounding_box_IoU_metric: 0.1749 - val_loss: 0.7431 - val_labels_loss: 0.5581 - val_bounding_box_loss: 0.0185 - val_labels_accuracy: 0.7201 - val_bounding_box_IoU_metric: 0.1418 - lr: 0.0010
# Epoch 11/20
# 43/43 [==============================] - ETA: 0s - loss: 0.6076 - labels_loss: 0.4428 - bounding_box_loss: 0.0165 - labels_accuracy: 0.7839 - bounding_box_IoU_metric: 0.1755
# Epoch 11: val_loss did not improve from 0.72242
# 43/43 [==============================] - 47s 1s/step - loss: 0.6076 - labels_loss: 0.4428 - bounding_box_loss: 0.0165 - labels_accuracy: 0.7839 - bounding_box_IoU_metric: 0.1755 - val_loss: 0.7471 - val_labels_loss: 0.5658 - val_bounding_box_loss: 0.0181 - val_labels_accuracy: 0.7289 - val_bounding_box_IoU_metric: 0.1831 - lr: 0.0010
# Epoch 12/20
# 43/43 [==============================] - ETA: 0s - loss: 0.5874 - labels_loss: 0.4302 - bounding_box_loss: 0.0157 - labels_accuracy: 0.7942 - bounding_box_IoU_metric: 0.1819
# Epoch 12: val_loss did not improve from 0.72242
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 43/43 [==============================] - 47s 1s/step - loss: 0.5874 - labels_loss: 0.4302 - bounding_box_loss: 0.0157 - labels_accuracy: 0.7942 - bounding_box_IoU_metric: 0.1819 - val_loss: 0.7274 - val_labels_loss: 0.5495 - val_bounding_box_loss: 0.0178 - val_labels_accuracy: 0.7464 - val_bounding_box_IoU_metric: 0.1744 - lr: 0.0010
# Epoch 13/20
# 43/43 [==============================] - ETA: 0s - loss: 0.4893 - labels_loss: 0.3648 - bounding_box_loss: 0.0125 - labels_accuracy: 0.8204 - bounding_box_IoU_metric: 0.2098
# Epoch 13: val_loss improved from 0.72242 to 0.67693, saving model to models/scratch_cnn_exp5.h5
# 43/43 [==============================] - 49s 1s/step - loss: 0.4893 - labels_loss: 0.3648 - bounding_box_loss: 0.0125 - labels_accuracy: 0.8204 - bounding_box_IoU_metric: 0.2098 - val_loss: 0.6769 - val_labels_loss: 0.5160 - val_bounding_box_loss: 0.0161 - val_labels_accuracy: 0.7434 - val_bounding_box_IoU_metric: 0.1771 - lr: 2.0000e-04
# Epoch 14/20
# 43/43 [==============================] - ETA: 0s - loss: 0.4529 - labels_loss: 0.3393 - bounding_box_loss: 0.0114 - labels_accuracy: 0.8358 - bounding_box_IoU_metric: 0.2186
# Epoch 14: val_loss did not improve from 0.67693
# 43/43 [==============================] - 47s 1s/step - loss: 0.4529 - labels_loss: 0.3393 - bounding_box_loss: 0.0114 - labels_accuracy: 0.8358 - bounding_box_IoU_metric: 0.2186 - val_loss: 0.6961 - val_labels_loss: 0.5351 - val_bounding_box_loss: 0.0161 - val_labels_accuracy: 0.7405 - val_bounding_box_IoU_metric: 0.1804 - lr: 2.0000e-04
# Epoch 15/20
# 43/43 [==============================] - ETA: 0s - loss: 0.4165 - labels_loss: 0.3070 - bounding_box_loss: 0.0109 - labels_accuracy: 0.8591 - bounding_box_IoU_metric: 0.2216
# Epoch 15: val_loss did not improve from 0.67693
# 43/43 [==============================] - 47s 1s/step - loss: 0.4165 - labels_loss: 0.3070 - bounding_box_loss: 0.0109 - labels_accuracy: 0.8591 - bounding_box_IoU_metric: 0.2216 - val_loss: 0.6977 - val_labels_loss: 0.5371 - val_bounding_box_loss: 0.0161 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.1732 - lr: 2.0000e-04
# Epoch 16/20
# 43/43 [==============================] - ETA: 0s - loss: 0.4019 - labels_loss: 0.3000 - bounding_box_loss: 0.0102 - labels_accuracy: 0.8562 - bounding_box_IoU_metric: 0.2368
# Epoch 16: val_loss did not improve from 0.67693
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 43/43 [==============================] - 49s 1s/step - loss: 0.4019 - labels_loss: 0.3000 - bounding_box_loss: 0.0102 - labels_accuracy: 0.8562 - bounding_box_IoU_metric: 0.2368 - val_loss: 0.6934 - val_labels_loss: 0.5309 - val_bounding_box_loss: 0.0162 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.1742 - lr: 2.0000e-04
# Epoch 17/20
# 43/43 [==============================] - ETA: 0s - loss: 0.3679 - labels_loss: 0.2690 - bounding_box_loss: 0.0099 - labels_accuracy: 0.8839 - bounding_box_IoU_metric: 0.2318
# Epoch 17: val_loss did not improve from 0.67693
# 43/43 [==============================] - 47s 1s/step - loss: 0.3679 - labels_loss: 0.2690 - bounding_box_loss: 0.0099 - labels_accuracy: 0.8839 - bounding_box_IoU_metric: 0.2318 - val_loss: 0.6800 - val_labels_loss: 0.5231 - val_bounding_box_loss: 0.0157 - val_labels_accuracy: 0.7580 - val_bounding_box_IoU_metric: 0.1791 - lr: 4.0000e-05
# Epoch 18/20
# 43/43 [==============================] - ETA: 0s - loss: 0.3686 - labels_loss: 0.2719 - bounding_box_loss: 0.0097 - labels_accuracy: 0.8839 - bounding_box_IoU_metric: 0.2443
# Epoch 18: val_loss did not improve from 0.67693
# 43/43 [==============================] - 47s 1s/step - loss: 0.3686 - labels_loss: 0.2719 - bounding_box_loss: 0.0097 - labels_accuracy: 0.8839 - bounding_box_IoU_metric: 0.2443 - val_loss: 0.6798 - val_labels_loss: 0.5232 - val_bounding_box_loss: 0.0157 - val_labels_accuracy: 0.7580 - val_bounding_box_IoU_metric: 0.1779 - lr: 4.0000e-05
# Epoch 19/20
# 43/43 [==============================] - ETA: 0s - loss: 0.3564 - labels_loss: 0.2632 - bounding_box_loss: 0.0093 - labels_accuracy: 0.8854 - bounding_box_IoU_metric: 0.2467
# Epoch 19: val_loss improved from 0.67693 to 0.67468, saving model to models/scratch_cnn_exp5.h5
# 43/43 [==============================] - 47s 1s/step - loss: 0.3564 - labels_loss: 0.2632 - bounding_box_loss: 0.0093 - labels_accuracy: 0.8854 - bounding_box_IoU_metric: 0.2467 - val_loss: 0.6747 - val_labels_loss: 0.5182 - val_bounding_box_loss: 0.0156 - val_labels_accuracy: 0.7551 - val_bounding_box_IoU_metric: 0.1783 - lr: 4.0000e-05
# Epoch 20/20
# 43/43 [==============================] - ETA: 0s - loss: 0.3518 - labels_loss: 0.2598 - bounding_box_loss: 0.0092 - labels_accuracy: 0.8847 - bounding_box_IoU_metric: 0.2534
# Epoch 20: val_loss improved from 0.67468 to 0.67394, saving model to models/scratch_cnn_exp5.h5
# 43/43 [==============================] - 49s 1s/step - loss: 0.3518 - labels_loss: 0.2598 - bounding_box_loss: 0.0092 - labels_accuracy: 0.8847 - bounding_box_IoU_metric: 0.2534 - val_loss: 0.6739 - val_labels_loss: 0.5169 - val_bounding_box_loss: 0.0157 - val_labels_accuracy: 0.7551 - val_bounding_box_IoU_metric: 0.1761 - lr: 4.0000e-05

# %%
#plot the history of the training

plt.figure(figsize=(12,5))
plt.title('labels loss')
plt.plot(history.history['labels_loss'],'bo-',label = 'train_labels_loss')
plt.plot(history.history['val_labels_loss'],'b-',label = 'val_labels_loss')
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('bbox loss')
plt.plot(history.history['bounding_box_loss'],'bo-',label = 'train_bounding_box_loss')
plt.plot(history.history['val_bounding_box_loss'],'b-',label = 'val_bounding_box_loss')
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('total loss')
plt.plot(history.history['loss'],'bo-',label = 'train_loss')
plt.plot(history.history['val_loss'],'b-',label = 'val_loss')
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('accuracy')
plt.plot(history.history['labels_accuracy'],'bo-',label = 'train_labels_accuracy')
plt.plot(history.history['val_labels_accuracy'],'b-',label = 'val_labels_accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('IoU scaled in [0,1]')
plt.plot(history.history['bounding_box_IoU_metric'],'bo-',label = 'train_bounding_box_IoU_metric')
plt.plot(history.history['val_bounding_box_IoU_metric'],'b-',label = 'val_bounding_box_IoU_metric')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model

# delete the current model
del model

# load the model saved by the early stopping callback
model = load_model(os.path.join(model_dir, experiment), custom_objects={"IoU_metric": IoU_metric})

#evaluate the model on the test set
model.evaluate({"input": feature_test_set},
               {"labels": labels_test_set, "bounding_box": bounding_box_test_set}, 
               return_dict=True)
# Out:
# 14/14 [==============================] - 4s 271ms/step - loss: 0.6955 - labels_loss: 0.5325 - bounding_box_loss: 0.0163 - labels_accuracy: 0.7617 - bounding_box_IoU_metric: 0.1936
# {'loss': 0.6954795122146606,
#  'labels_loss': 0.5325220227241516,
#  'bounding_box_loss': 0.016295744106173515,
#  'labels_accuracy': 0.7616822719573975,
#  'bounding_box_IoU_metric': 0.1936158835887909}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# create and plot the confusion matrix
predictions = model(feature_test_set)
result = confusion_matrix(labels_test_set, tf.cast(tf.math.round(predictions[0]), dtype=tf.int32), normalize='pred')
disp = ConfusionMatrixDisplay(confusion_matrix=result, display_labels=['without mask', 'with mask'])
disp.plot()
plt.show()

# %%
# save the model to google drive
# !cp ./models/scratch_cnn_exp5.h5 /content/drive/MyDrive/CIDL_Project/models/

# %%
# verify that the model was uploaded to drive
drive_dir_model = "/content/drive/MyDrive/CIDL_Project/models/"
experiment = "scratch_cnn_exp5.h5"
model = load_model(os.path.join(drive_dir_model, experiment), custom_objects={"IoU_metric": IoU_metric})
model.evaluate({"input": feature_test_set},
               {"labels": tf.keras.utils.to_categorical(labels_test_set), "bounding_box": bounding_box_test_set}, 
               return_dict=True)
