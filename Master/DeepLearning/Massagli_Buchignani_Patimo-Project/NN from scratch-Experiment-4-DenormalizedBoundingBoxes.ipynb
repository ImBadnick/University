# %% [markdown]
# # Experiment 4

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# download the dataset content from google drive to google colab vm (this is done for efficiency reasons)
# !cp -r /content/drive/MyDrive/CIDL_Project/dataset/preprocessed_annotations/preprocessed_annotations .
# !cp -r /content/drive/MyDrive/CIDL_Project/dataset/preprocessed_images/preprocessed_images .

# %%
import tensorflow as tf

# store the images using a keras utility
image_dataset = tf.keras.utils.image_dataset_from_directory(
    directory='./preprocessed_images',
    labels = None,
    label_mode=None,
    batch_size=None,
    color_mode='rgb',
    # specify the size of the images, all the images are rescaled to this size
    image_size=(128, 128),
    shuffle=False,
    crop_to_aspect_ratio=False,
)
# Out:
# Found 1861 files belonging to 1 classes.

# %% [markdown]
# The functions in the next cell are an adaptation of the code used in the [Keras tutorial of RetinaNet](https://keras.io/examples/vision/retinanet/)

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ["without mask", "with mask"]

def visualize_image(image, figsize=(7, 7)):
    image = np.array(image, dtype=np.uint8)
    plt.figure()
    plt.axis("off")
    plt.imshow(image)
    return plt

def visualize_images(images, figsize=(7, 7)):
  for image in images:
    visualize_image(image, figsize)

def visualize_detections(
    image, box, label, figsize=(7, 7), linewidth=1, color=[0, 0, 1]
):
    # the function gets as input the image, the bounding box in xmin, ymin, xmax and ymax format and the label as an integer (0 or 1)
    plt = visualize_image(image)
    ax = plt.gca()
    text = "{}:".format(labels[label])
    x1, y1, x2, y2 = box
    w, h = x2 - x1, y2 - y1
    patch = plt.Rectangle(
        [x1, y1], w, h, fill=False, edgecolor=color, linewidth=linewidth
    )
    ax.add_patch(patch)
    ax.text(
        x1,
        y1,
        text,
        bbox={"facecolor": color, "alpha": 0.4},
        clip_box=ax.clipbox,
        clip_on=True,
    )
    plt.show()
    return ax

# %%
def rescale_bbox(image_shape, bbox):
  # bbox is a tensor with the normalized coordinates of the bounding box expressed in xmin, ymin, xmax, ymax format
  # the function denormalizes the coordinates and returns the corresponding tensor
  return tf.stack(
        [
            bbox[0] * image_shape[1],
            bbox[1] * image_shape[0],
            bbox[2] * image_shape[1],
            bbox[3] * image_shape[0]
        ])

# %% [markdown]
# The functions in the next cell are an adaptation of the code used in the [Keras tutorial of RetinaNet](https://keras.io/examples/vision/retinanet/)
#
# The coordinates of the bounding boxes can be expressed in two formats:
# *   xmin, ymin, xmax, ymax (minmax for short)
# *   xcenter, ycenter, width, height (xywh for short)
#
# The two functions below convert a format to the other one and viceversa.
#
# Both are needed because to visualize them we need the first format, while the format used to train the network is the second

# %%
def convert_to_xywh(boxes):
    return tf.concat(
        [(boxes[..., :2] + boxes[..., 2:]) / 2.0, boxes[..., 2:] - boxes[..., :2]],
        axis=-1,
    )

def convert_to_minmax(boxes):
    return tf.concat(
        [boxes[..., :2] - boxes[..., 2:] / 2.0, boxes[..., :2] + boxes[..., 2:] / 2.0],
        axis=-1,
    )

# %%
def flip_horizontal(image, boxes):
    # we flip the image given in input and modify accordingly the bounding boxes, which are here expressed in xywh
    flipped_image = tf.image.flip_left_right(image)
    flipped_boxes = tf.stack(
        [1 - boxes[0], boxes[1], boxes[2], boxes[3]], axis=-1
    )
    return flipped_image, flipped_boxes

# %%
def preprocess_data(sample):
    # sample is a dictionary containing all the relevant information about an image
    # normalize each coordinate on the basis of the original width and height of the image
    normalized_xmin = sample["xmin"] / sample["width"]
    normalized_ymin = sample["ymin"] / sample["height"]
    normalized_xmax = sample["xmax"] / sample["width"]
    normalized_ymax = sample["ymax"] / sample["height"]
    # convert the list of coordinates into a tensor and in xywh format
    bounding_box = [normalized_xmin, normalized_ymin, normalized_xmax, normalized_ymax]
    bboxes = tf.convert_to_tensor(bounding_box)
    bboxes = convert_to_xywh(bboxes)
    label = tf.convert_to_tensor(sample["label"], dtype=tf.float32)
    ground_truth = tf.stack(
        [
            bboxes[0],
            bboxes[1],
            bboxes[2],
            bboxes[3]
        ],
        axis=-1,
    )
    return ground_truth, label

# %% [markdown]
# In the next cell we take each image, we parse the relative annotation file to get the relevant information and we create the dataset

# %%
import os

path = "preprocessed_annotations"
i = 0

annotations = os.listdir(path)
# sorting in lexicographic order is needed to match image ordering
annotations.sort()

list_of_features = []
list_of_bboxes = []
list_of_labels = []
for image in image_dataset:
  
  # get the path of the annotation file corresponding to the image
  file_name = annotations[i]
  file_path = os.path.join(path, file_name)

  sample = {}
  
  with open(file_path, 'r') as f:
    # fill the dictionary with the relevant information
    sample["width"] = int(f.readline())
    sample["height"] = int(f.readline())
    sample["xmin"] = int(f.readline())
    sample["ymin"] = int(f.readline())
    sample["xmax"] = int(f.readline())
    sample["ymax"] = int(f.readline())
    # label is here normalized as a value contained in the set {0, 1}.
    # In the annotation file 1 stands for class "without mask" and 2 stands for class "with mask", here we set 0 as "without mask" and 1 as "with mask"
    sample["label"] = int(f.readline()) - 1
    bounding_box, label = preprocess_data(sample)
    # denormalize the bounding box with respect to the actual shape of the image fed to the network
    target_bounding_box = rescale_bbox(image.shape, bounding_box)
  list_of_features.append(image)
  list_of_bboxes.append(target_bounding_box)
  list_of_labels.append(label)
  # if the image belongs to class "withouth mask" generate the flipped image to augment the dataset
  if sample["label"] == 0:
    flipped_image, flipped_bbox = flip_horizontal(image, bounding_box)
    flipped_target_bbox = rescale_bbox(image.shape, flipped_bbox)
    list_of_features.append(flipped_image)
    list_of_bboxes.append(flipped_target_bbox)
    list_of_labels.append(label)
  i = i + 1
  if (i % 200 == 0):
    print(i)

feature_tensor = tf.convert_to_tensor(list_of_features)
bounding_box_tensor = tf.convert_to_tensor(list_of_bboxes)
# to categorical
labels_tensor = tf.keras.utils.to_categorical(tf.convert_to_tensor(list_of_labels))

# set test size
test_set_size = int(np.floor(feature_tensor.shape[0]*0.2))
# Out:
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800

# %%
# shuffle the three tensors in such a way the elements remained coupled across tensors
random_seed = 100
tf.random.set_seed(random_seed)
feature_tensor = tf.random.shuffle(feature_tensor)
tf.random.set_seed(random_seed)
bounding_box_tensor = tf.random.shuffle(bounding_box_tensor)
tf.random.set_seed(random_seed)
labels_tensor = tf.random.shuffle(labels_tensor)

# %%
# verify that each bounding box and each label is still at the same index as the relative image
index = 1540
bbox = convert_to_minmax(bounding_box_tensor[index])
label = 0 if labels_tensor[index][1].numpy() == 0 else 1
visualize_detections(feature_tensor[index], bbox, label)

# %%
# split in training set and test set
feature_test_set = feature_tensor[:test_set_size]
feature_tensor = feature_tensor[test_set_size:]
bounding_box_test_set = bounding_box_tensor[:test_set_size]
bounding_box_tensor = bounding_box_tensor[test_set_size:]
labels_test_set = labels_tensor[:test_set_size]
labels_tensor = labels_tensor[test_set_size:]

# %% [markdown]
# The function in the next cell is an adaptation of the code used in the [Keras tutorial of RetinaNet](https://keras.io/examples/vision/retinanet/)
#
# The function is used as a callback metric during training and test for measuring the performance of the regression head

# %%
def IoU_metric(y_true, y_pred):
    # y_true is a tensor representing the ground truth bounding boxes for a given batch of samples (in format xywh)
    # y_pred is a tensor representing the predicted bounding boxes for the same batch of samples (in format xywh)
    # the function computes the IoU score for each couple (ground truth bounding box, predicted bounding box)
    boxes1_corners = convert_to_minmax(y_true)
    boxes2_corners = convert_to_minmax(y_pred)
    # compute the intersection area
    lu = tf.maximum(boxes1_corners[:, :2], boxes2_corners[:, :2])
    rd = tf.minimum(boxes1_corners[:, 2:], boxes2_corners[:, 2:])
    intersection = tf.maximum(0.0, rd - lu)
    intersection_area = intersection[:, 0] * intersection[:, 1]
    # compute the union area
    boxes1_area = y_true[:, 2] * y_true[:, 3]
    boxes2_area = y_pred[:, 2] * y_pred[:, 3]  
    union_area = tf.maximum(
        boxes1_area + boxes2_area - intersection_area, 1e-8
    )
    # compute IoU
    return tf.clip_by_value(intersection_area / union_area, 0.0, 1.0)

# %% [markdown]
# The function in the next cell is an adaptation of the code used in the [Keras tutorial of RetinaNet](https://keras.io/examples/vision/retinanet/)
#
# The function implements the smooth-l1 loss and extends the Loss class of Keras, in such a way that can be used as a custom loss during the training of the model. The variant presented here is the [Huber loss](https://en.wikipedia.org/wiki/Huber_loss).

# %%
import tensorflow as tf
class SmoothL1Loss(tf.losses.Loss):

    def __init__(self, delta):
        super().__init__(
            name="Smooth_L1_Loss"
        )

        #delta is the threshold parameter (see link above on Huber loss for reference)
        self._delta = delta

    def call(self, y_true, y_pred):
        # computes smooth-L1 for each coordinate of the couple of bounding boxes
        difference = y_true - y_pred
        absolute_difference = tf.abs(difference)
        squared_difference = difference ** 2
        loss = tf.where(
            tf.less(absolute_difference, self._delta),
            0.5 * squared_difference,
            self._delta*(absolute_difference - 0.5*self._delta),
        )
        # returns the mean over the coordinates
        return tf.reduce_mean(loss, axis=-1)

# %% [markdown]
# # Experiment 4, Mean Squared Error Loss

# %%
from tensorflow import keras

# instantiate the model
input = keras.Input(shape=(128,128,3), name="input")
model = keras.layers.Conv2D(32, (3, 3), activation='relu')(input)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(64, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(128, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(256, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Flatten()(model)
dropout_cls = keras.layers.Dropout(0.6)(model)
dropout_box = keras.layers.Dropout(0.1)(model)
classification_head = keras.layers.Dense(2, activation='softmax', name="labels")(dropout_cls)
regression_head = keras.layers.Dense(4, activation='linear', name="bounding_box")(dropout_box)

# %%
# define input and outputs of the model
model = keras.Model(
    inputs=input,
    outputs=[classification_head, regression_head],
)

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 126, 126, 32  896         ['input[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 63, 63, 32)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 61, 61, 64)   18496       ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 30, 30, 64)  0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 28, 28, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 128)  0          ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 12, 12, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 256)   0           ['conv2d_3[0][0]']
#
#  flatten (Flatten)              (None, 9216)         0           ['max_pooling2d_3[0][0]']
#
#  dropout (Dropout)              (None, 9216)         0           ['flatten[0][0]']
#
#  dropout_1 (Dropout)            (None, 9216)         0           ['flatten[0][0]']
#
#  labels (Dense)                 (None, 2)            18434       ['dropout[0][0]']
#
#  bounding_box (Dense)           (None, 4)            36868       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 443,718
# Trainable params: 443,718
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# compile the model
model.compile(
    optimizer=keras.optimizers.RMSprop(1e-3),

    # define which loss to use for each head of the network
    loss={
        "bounding_box": keras.losses.MeanSquaredError(),
        "labels": keras.losses.CategoricalCrossentropy(),
    },

    # the total loss is a linear combination of the two losses of the network, here we define the weights of each loss
    # bounding box weight was reduced with respect to previous experiment because now we have pixels instead of normalized values and mse is higher 
    loss_weights={"labels": 1.0, "bounding_box": 1.0},
    metrics={'labels':'accuracy', 'bounding_box': [IoU_metric]}
)

# this is done to implement early stopping
model_dir = "models/"
experiment = "scratch_cnn_exp4_mse.h5"
save_path = os.path.join(model_dir, experiment)

callbacks_list = [
    keras.callbacks.ModelCheckpoint(
    filepath=save_path,
    # we save the model with the lowest validation total loss
    monitor="val_loss",
    verbose=1,
    save_best_only=True)
]

# %%
history = model.fit(
              {"input": feature_tensor},
              {"labels": labels_tensor, "bounding_box": bounding_box_tensor},
              epochs=20,
              batch_size=32,
              validation_split=0.2,
              shuffle=True,
              callbacks = callbacks_list
          )
# Out:
# Epoch 1/20
# 43/43 [==============================] - ETA: 0s - loss: 12154.9287 - labels_loss: 15.6837 - bounding_box_loss: 12139.2412 - labels_accuracy: 0.6219 - bounding_box_IoU_metric: 0.0819
# Epoch 1: val_loss improved from inf to 481.40607, saving model to models/scratch_cnn_exp4_mse.h5
# 43/43 [==============================] - 53s 1s/step - loss: 12154.9287 - labels_loss: 15.6837 - bounding_box_loss: 12139.2412 - labels_accuracy: 0.6219 - bounding_box_IoU_metric: 0.0819 - val_loss: 481.4061 - val_labels_loss: 11.7291 - val_bounding_box_loss: 469.6770 - val_labels_accuracy: 0.2507 - val_bounding_box_IoU_metric: 0.0960
# Epoch 2/20
# 43/43 [==============================] - ETA: 0s - loss: 503.0287 - labels_loss: 6.0358 - bounding_box_loss: 496.9931 - labels_accuracy: 0.6314 - bounding_box_IoU_metric: 0.1021
# Epoch 2: val_loss did not improve from 481.40607
# 43/43 [==============================] - 51s 1s/step - loss: 503.0287 - labels_loss: 6.0358 - bounding_box_loss: 496.9931 - labels_accuracy: 0.6314 - bounding_box_IoU_metric: 0.1021 - val_loss: 821.8758 - val_labels_loss: 2.6973 - val_bounding_box_loss: 819.1786 - val_labels_accuracy: 0.7464 - val_bounding_box_IoU_metric: 0.0656
# Epoch 3/20
# 43/43 [==============================] - ETA: 0s - loss: 771.5608 - labels_loss: 3.8689 - bounding_box_loss: 767.6919 - labels_accuracy: 0.6226 - bounding_box_IoU_metric: 0.0739
# Epoch 3: val_loss did not improve from 481.40607
# 43/43 [==============================] - 51s 1s/step - loss: 771.5608 - labels_loss: 3.8689 - bounding_box_loss: 767.6919 - labels_accuracy: 0.6226 - bounding_box_IoU_metric: 0.0739 - val_loss: 567.0223 - val_labels_loss: 0.6618 - val_bounding_box_loss: 566.3604 - val_labels_accuracy: 0.7230 - val_bounding_box_IoU_metric: 0.0759
# Epoch 4/20
# 43/43 [==============================] - ETA: 0s - loss: 563.4828 - labels_loss: 2.5303 - bounding_box_loss: 560.9525 - labels_accuracy: 0.6401 - bounding_box_IoU_metric: 0.0890
# Epoch 4: val_loss improved from 481.40607 to 384.06720, saving model to models/scratch_cnn_exp4_mse.h5
# 43/43 [==============================] - 53s 1s/step - loss: 563.4828 - labels_loss: 2.5303 - bounding_box_loss: 560.9525 - labels_accuracy: 0.6401 - bounding_box_IoU_metric: 0.0890 - val_loss: 384.0672 - val_labels_loss: 1.1438 - val_bounding_box_loss: 382.9234 - val_labels_accuracy: 0.7464 - val_bounding_box_IoU_metric: 0.1171
# Epoch 5/20
# 43/43 [==============================] - ETA: 0s - loss: 535.8517 - labels_loss: 2.1787 - bounding_box_loss: 533.6729 - labels_accuracy: 0.6672 - bounding_box_IoU_metric: 0.1012
# Epoch 5: val_loss improved from 384.06720 to 373.81122, saving model to models/scratch_cnn_exp4_mse.h5
# 43/43 [==============================] - 51s 1s/step - loss: 535.8517 - labels_loss: 2.1787 - bounding_box_loss: 533.6729 - labels_accuracy: 0.6672 - bounding_box_IoU_metric: 0.1012 - val_loss: 373.8112 - val_labels_loss: 3.3755 - val_bounding_box_loss: 370.4358 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.1331
# Epoch 6/20
# 43/43 [==============================] - ETA: 0s - loss: 449.5757 - labels_loss: 2.1622 - bounding_box_loss: 447.4135 - labels_accuracy: 0.6730 - bounding_box_IoU_metric: 0.1159
# Epoch 6: val_loss did not improve from 373.81122
# 43/43 [==============================] - 50s 1s/step - loss: 449.5757 - labels_loss: 2.1622 - bounding_box_loss: 447.4135 - labels_accuracy: 0.6730 - bounding_box_IoU_metric: 0.1159 - val_loss: 424.3505 - val_labels_loss: 2.3415 - val_bounding_box_loss: 422.0090 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.1094
# Epoch 7/20
# 43/43 [==============================] - ETA: 0s - loss: 414.0350 - labels_loss: 2.1253 - bounding_box_loss: 411.9097 - labels_accuracy: 0.6416 - bounding_box_IoU_metric: 0.1244
# Epoch 7: val_loss did not improve from 373.81122
# 43/43 [==============================] - 52s 1s/step - loss: 414.0350 - labels_loss: 2.1253 - bounding_box_loss: 411.9097 - labels_accuracy: 0.6416 - bounding_box_IoU_metric: 0.1244 - val_loss: 391.4481 - val_labels_loss: 4.2418 - val_bounding_box_loss: 387.2063 - val_labels_accuracy: 0.3469 - val_bounding_box_IoU_metric: 0.1435
# Epoch 8/20
# 43/43 [==============================] - ETA: 0s - loss: 411.2692 - labels_loss: 2.1140 - bounding_box_loss: 409.1551 - labels_accuracy: 0.6818 - bounding_box_IoU_metric: 0.1353
# Epoch 8: val_loss did not improve from 373.81122
# 43/43 [==============================] - 53s 1s/step - loss: 411.2692 - labels_loss: 2.1140 - bounding_box_loss: 409.1551 - labels_accuracy: 0.6818 - bounding_box_IoU_metric: 0.1353 - val_loss: 395.8842 - val_labels_loss: 0.9845 - val_bounding_box_loss: 394.8997 - val_labels_accuracy: 0.7055 - val_bounding_box_IoU_metric: 0.1131
# Epoch 9/20
# 43/43 [==============================] - ETA: 0s - loss: 353.7283 - labels_loss: 1.6099 - bounding_box_loss: 352.1184 - labels_accuracy: 0.7117 - bounding_box_IoU_metric: 0.1504
# Epoch 9: val_loss improved from 373.81122 to 319.44382, saving model to models/scratch_cnn_exp4_mse.h5
# 43/43 [==============================] - 51s 1s/step - loss: 353.7283 - labels_loss: 1.6099 - bounding_box_loss: 352.1184 - labels_accuracy: 0.7117 - bounding_box_IoU_metric: 0.1504 - val_loss: 319.4438 - val_labels_loss: 1.5264 - val_bounding_box_loss: 317.9174 - val_labels_accuracy: 0.7493 - val_bounding_box_IoU_metric: 0.1539
# Epoch 10/20
# 43/43 [==============================] - ETA: 0s - loss: 330.8222 - labels_loss: 1.7979 - bounding_box_loss: 329.0243 - labels_accuracy: 0.6993 - bounding_box_IoU_metric: 0.1633
# Epoch 10: val_loss did not improve from 319.44382
# 43/43 [==============================] - 51s 1s/step - loss: 330.8222 - labels_loss: 1.7979 - bounding_box_loss: 329.0243 - labels_accuracy: 0.6993 - bounding_box_IoU_metric: 0.1633 - val_loss: 558.3797 - val_labels_loss: 1.5913 - val_bounding_box_loss: 556.7884 - val_labels_accuracy: 0.7668 - val_bounding_box_IoU_metric: 0.1020
# Epoch 11/20
# 43/43 [==============================] - ETA: 0s - loss: 310.0418 - labels_loss: 1.8150 - bounding_box_loss: 308.2268 - labels_accuracy: 0.7073 - bounding_box_IoU_metric: 0.1639
# Epoch 11: val_loss did not improve from 319.44382
# 43/43 [==============================] - 51s 1s/step - loss: 310.0418 - labels_loss: 1.8150 - bounding_box_loss: 308.2268 - labels_accuracy: 0.7073 - bounding_box_IoU_metric: 0.1639 - val_loss: 799.1390 - val_labels_loss: 1.1850 - val_bounding_box_loss: 797.9540 - val_labels_accuracy: 0.7580 - val_bounding_box_IoU_metric: 0.0149
# Epoch 12/20
# 43/43 [==============================] - ETA: 0s - loss: 292.8130 - labels_loss: 1.6147 - bounding_box_loss: 291.1983 - labels_accuracy: 0.7212 - bounding_box_IoU_metric: 0.1712
# Epoch 12: val_loss did not improve from 319.44382
# 43/43 [==============================] - 51s 1s/step - loss: 292.8130 - labels_loss: 1.6147 - bounding_box_loss: 291.1983 - labels_accuracy: 0.7212 - bounding_box_IoU_metric: 0.1712 - val_loss: 375.4164 - val_labels_loss: 2.0327 - val_bounding_box_loss: 373.3837 - val_labels_accuracy: 0.7405 - val_bounding_box_IoU_metric: 0.1691
# Epoch 13/20
# 43/43 [==============================] - ETA: 0s - loss: 272.8356 - labels_loss: 1.5678 - bounding_box_loss: 271.2679 - labels_accuracy: 0.7504 - bounding_box_IoU_metric: 0.1854
# Epoch 13: val_loss did not improve from 319.44382
# 43/43 [==============================] - 53s 1s/step - loss: 272.8356 - labels_loss: 1.5678 - bounding_box_loss: 271.2679 - labels_accuracy: 0.7504 - bounding_box_IoU_metric: 0.1854 - val_loss: 456.0467 - val_labels_loss: 1.3093 - val_bounding_box_loss: 454.7374 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.0833
# Epoch 14/20
# 43/43 [==============================] - ETA: 0s - loss: 227.1717 - labels_loss: 1.3442 - bounding_box_loss: 225.8275 - labels_accuracy: 0.7745 - bounding_box_IoU_metric: 0.2048
# Epoch 14: val_loss did not improve from 319.44382
# 43/43 [==============================] - 51s 1s/step - loss: 227.1717 - labels_loss: 1.3442 - bounding_box_loss: 225.8275 - labels_accuracy: 0.7745 - bounding_box_IoU_metric: 0.2048 - val_loss: 340.0284 - val_labels_loss: 2.2476 - val_bounding_box_loss: 337.7807 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.1435
# Epoch 15/20
# 43/43 [==============================] - ETA: 0s - loss: 231.0345 - labels_loss: 1.4020 - bounding_box_loss: 229.6325 - labels_accuracy: 0.7723 - bounding_box_IoU_metric: 0.1909
# Epoch 15: val_loss did not improve from 319.44382
# 43/43 [==============================] - 51s 1s/step - loss: 231.0345 - labels_loss: 1.4020 - bounding_box_loss: 229.6325 - labels_accuracy: 0.7723 - bounding_box_IoU_metric: 0.1909 - val_loss: 366.8485 - val_labels_loss: 2.0454 - val_bounding_box_loss: 364.8031 - val_labels_accuracy: 0.7580 - val_bounding_box_IoU_metric: 0.1161
# Epoch 16/20
# 43/43 [==============================] - ETA: 0s - loss: 201.3264 - labels_loss: 1.1662 - bounding_box_loss: 200.1602 - labels_accuracy: 0.7993 - bounding_box_IoU_metric: 0.2107
# Epoch 16: val_loss improved from 319.44382 to 314.94363, saving model to models/scratch_cnn_exp4_mse.h5
# 43/43 [==============================] - 51s 1s/step - loss: 201.3264 - labels_loss: 1.1662 - bounding_box_loss: 200.1602 - labels_accuracy: 0.7993 - bounding_box_IoU_metric: 0.2107 - val_loss: 314.9436 - val_labels_loss: 1.7010 - val_bounding_box_loss: 313.2427 - val_labels_accuracy: 0.7289 - val_bounding_box_IoU_metric: 0.1816
# Epoch 17/20
# 43/43 [==============================] - ETA: 0s - loss: 185.9783 - labels_loss: 1.2408 - bounding_box_loss: 184.7376 - labels_accuracy: 0.8015 - bounding_box_IoU_metric: 0.2240
# Epoch 17: val_loss did not improve from 314.94363
# 43/43 [==============================] - 53s 1s/step - loss: 185.9783 - labels_loss: 1.2408 - bounding_box_loss: 184.7376 - labels_accuracy: 0.8015 - bounding_box_IoU_metric: 0.2240 - val_loss: 359.1617 - val_labels_loss: 2.4558 - val_bounding_box_loss: 356.7059 - val_labels_accuracy: 0.7638 - val_bounding_box_IoU_metric: 0.1471
# Epoch 18/20
# 43/43 [==============================] - ETA: 0s - loss: 167.8096 - labels_loss: 1.2042 - bounding_box_loss: 166.6054 - labels_accuracy: 0.8088 - bounding_box_IoU_metric: 0.2402
# Epoch 18: val_loss did not improve from 314.94363
# 43/43 [==============================] - 51s 1s/step - loss: 167.8096 - labels_loss: 1.2042 - bounding_box_loss: 166.6054 - labels_accuracy: 0.8088 - bounding_box_IoU_metric: 0.2402 - val_loss: 437.4310 - val_labels_loss: 2.3336 - val_bounding_box_loss: 435.0974 - val_labels_accuracy: 0.7085 - val_bounding_box_IoU_metric: 0.1546
# Epoch 19/20
# 43/43 [==============================] - ETA: 0s - loss: 157.0908 - labels_loss: 1.1258 - bounding_box_loss: 155.9649 - labels_accuracy: 0.8124 - bounding_box_IoU_metric: 0.2481
# Epoch 19: val_loss did not improve from 314.94363
# 43/43 [==============================] - 50s 1s/step - loss: 157.0908 - labels_loss: 1.1258 - bounding_box_loss: 155.9649 - labels_accuracy: 0.8124 - bounding_box_IoU_metric: 0.2481 - val_loss: 356.3137 - val_labels_loss: 1.7697 - val_bounding_box_loss: 354.5440 - val_labels_accuracy: 0.7201 - val_bounding_box_IoU_metric: 0.1470
# Epoch 20/20
# 43/43 [==============================] - ETA: 0s - loss: 152.4418 - labels_loss: 1.0710 - bounding_box_loss: 151.3708 - labels_accuracy: 0.8197 - bounding_box_IoU_metric: 0.2406
# Epoch 20: val_loss did not improve from 314.94363
# 43/43 [==============================] - 51s 1s/step - loss: 152.4418 - labels_loss: 1.0710 - bounding_box_loss: 151.3708 - labels_accuracy: 0.8197 - bounding_box_IoU_metric: 0.2406 - val_loss: 315.0226 - val_labels_loss: 1.8686 - val_bounding_box_loss: 313.1540 - val_labels_accuracy: 0.7405 - val_bounding_box_IoU_metric: 0.1735

# %%
#plot the history of the training

plt.figure(figsize=(12,5))
plt.title('labels loss')
plt.plot(history.history['labels_loss'],'bo-',label = 'train_labels_loss')
plt.plot(history.history['val_labels_loss'],'b-',label = 'val_labels_loss')
plt.ylim(0, 5)
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('bbox loss')
plt.plot(history.history['bounding_box_loss'],'bo-',label = 'train_bounding_box_loss')
plt.plot(history.history['val_bounding_box_loss'],'b-',label = 'val_bounding_box_loss')
plt.ylim(0, 2000)
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('total loss')
plt.plot(history.history['loss'],'bo-',label = 'train_loss')
plt.plot(history.history['val_loss'],'b-',label = 'val_loss')
plt.ylim(0, 2000)
plt.legend()
plt.show()


plt.figure(figsize=(12,5))
plt.title('accuracy')
plt.plot(history.history['labels_accuracy'],'bo-',label = 'train_labels_accuracy')
plt.plot(history.history['val_labels_accuracy'],'b-',label = 'val_labels_accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('IoU scaled in [0,1]')
plt.plot(history.history['bounding_box_IoU_metric'],'bo-',label = 'train_bounding_box_IoU_metric')
plt.plot(history.history['val_bounding_box_IoU_metric'],'b-',label = 'val_bounding_box_IoU_metric')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model

# delete the current model
del model

# load the model saved by the early stopping callback
model = load_model(os.path.join(model_dir, experiment), custom_objects={"IoU_metric": IoU_metric})

#evaluate the model on the test set
model.evaluate({"input": feature_test_set},
               {"labels": labels_test_set, "bounding_box": bounding_box_test_set}, 
               return_dict=True)
# Out:
# 14/14 [==============================] - 4s 281ms/step - loss: 318.6938 - labels_loss: 1.9559 - bounding_box_loss: 316.7378 - labels_accuracy: 0.7477 - bounding_box_IoU_metric: 0.1838
# {'loss': 318.6937561035156,
#  'labels_loss': 1.9558970928192139,
#  'bounding_box_loss': 316.73779296875,
#  'labels_accuracy': 0.7476635575294495,
#  'bounding_box_IoU_metric': 0.1837986260652542}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# create and plot the confusion matrix
predictions = model(feature_test_set)
result = confusion_matrix(tf.math.argmax(labels_test_set, axis=1), tf.math.argmax(predictions[0], axis=1), normalize='pred')
disp = ConfusionMatrixDisplay(confusion_matrix=result, display_labels=['without mask', 'with mask'])
disp.plot()
plt.show()

# %%
# save the model to google drive
# !cp ./models/scratch_cnn_exp4_mse.h5 /content/drive/MyDrive/CIDL_Project/models/

# %%
# verify that the model was uploaded to drive
experiment = "scratch_cnn_exp4_mse.h5"
drive_dir_model = "/content/drive/MyDrive/CIDL_Project/models/"
model = load_model(os.path.join(drive_dir_model, experiment), custom_objects={"IoU_metric": IoU_metric})
model.evaluate({"input": feature_test_set},
               {"labels": labels_test_set, "bounding_box": bounding_box_test_set}, 
               return_dict=True)
# Out:
# 14/14 [==============================] - 4s 282ms/step - loss: 318.6938 - labels_loss: 1.9559 - bounding_box_loss: 316.7378 - labels_accuracy: 0.7477 - bounding_box_IoU_metric: 0.1838
# {'loss': 318.6937561035156,
#  'labels_loss': 1.9558970928192139,
#  'bounding_box_loss': 316.73779296875,
#  'labels_accuracy': 0.7476635575294495,
#  'bounding_box_IoU_metric': 0.1837986260652542}

# %% [markdown]
# # Experiment 4, Smooth-L1 loss

# %%
del model
# instantiate the model
input = keras.Input(shape=(128,128,3), name="input")
model = keras.layers.Conv2D(32, (3, 3), activation='relu')(input)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(64, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(128, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Conv2D(256, (3, 3), activation='relu')(model)
model = keras.layers.MaxPooling2D((2, 2))(model)
model = keras.layers.Flatten()(model)
dropout_cls = keras.layers.Dropout(0.6)(model)
dropout_box = keras.layers.Dropout(0.1)(model)
classification_head = keras.layers.Dense(2, activation='softmax', name="labels")(dropout_cls)
regression_head = keras.layers.Dense(4, activation='linear', name="bounding_box")(dropout_box)

# %%
# instantiate the smooth-L1 loss with threshold equal 1
smooth_L1_loss = SmoothL1Loss(1)

# %%
# define input and outputs of the model
model = keras.Model(
    inputs=input,
    outputs=[classification_head, regression_head],
)

# %%
# compile the model
model.compile(
    optimizer=keras.optimizers.RMSprop(1e-3),
    # define which loss to use for each head of the network
    loss={
        # here we use our custom loss
        "bounding_box": smooth_L1_loss,
        "labels": keras.losses.CategoricalCrossentropy(),
    },

    # the total loss is a linear combination of the two losses of the network, here we define the weights of each loss
    loss_weights={"labels": 1.0, "bounding_box": 1.0},

    # define which metrics to use for each head of the network, here we select our custom callback function IoU_metric() for the regression head
    metrics={'labels':'accuracy', 'bounding_box': [IoU_metric]}
)

# this is done to implement early stopping
model_dir = "models/"
experiment = "scratch_cnn_exp4_smooth-L1.h5"
save_path = os.path.join(model_dir, experiment)

callbacks_list = [
    keras.callbacks.ModelCheckpoint(
    filepath=save_path,
    # we save the model with the lowest validation total loss
    monitor="val_loss",
    verbose=1,
    save_best_only=True)
]

# %%
history = model.fit(
              {"input": feature_tensor},
              {"labels": labels_tensor, "bounding_box": bounding_box_tensor},
              epochs=20,
              batch_size=32,
              validation_split=0.2,
              shuffle=True,
              callbacks = callbacks_list
          )
# Out:
# Epoch 1/20
# 43/43 [==============================] - ETA: 0s - loss: 46.0269 - labels_loss: 8.5849 - bounding_box_loss: 37.4420 - labels_accuracy: 0.6270 - bounding_box_IoU_metric: 0.0701
# Epoch 1: val_loss improved from inf to 20.28571, saving model to models/scratch_cnn_exp4_smooth-L1.h5
# 43/43 [==============================] - 54s 1s/step - loss: 46.0269 - labels_loss: 8.5849 - bounding_box_loss: 37.4420 - labels_accuracy: 0.6270 - bounding_box_IoU_metric: 0.0701 - val_loss: 20.2857 - val_labels_loss: 1.0876 - val_bounding_box_loss: 19.1981 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.0730
# Epoch 2/20
# 43/43 [==============================] - ETA: 0s - loss: 22.0735 - labels_loss: 2.5090 - bounding_box_loss: 19.5645 - labels_accuracy: 0.6234 - bounding_box_IoU_metric: 0.0717
# Epoch 2: val_loss did not improve from 20.28571
# 43/43 [==============================] - 49s 1s/step - loss: 22.0735 - labels_loss: 2.5090 - bounding_box_loss: 19.5645 - labels_accuracy: 0.6234 - bounding_box_IoU_metric: 0.0717 - val_loss: 20.5215 - val_labels_loss: 2.9753 - val_bounding_box_loss: 17.5462 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.0838
# Epoch 3/20
# 43/43 [==============================] - ETA: 0s - loss: 20.5772 - labels_loss: 1.8363 - bounding_box_loss: 18.7409 - labels_accuracy: 0.6423 - bounding_box_IoU_metric: 0.0754
# Epoch 3: val_loss improved from 20.28571 to 17.75670, saving model to models/scratch_cnn_exp4_smooth-L1.h5
# 43/43 [==============================] - 49s 1s/step - loss: 20.5772 - labels_loss: 1.8363 - bounding_box_loss: 18.7409 - labels_accuracy: 0.6423 - bounding_box_IoU_metric: 0.0754 - val_loss: 17.7567 - val_labels_loss: 0.6538 - val_bounding_box_loss: 17.1029 - val_labels_accuracy: 0.6414 - val_bounding_box_IoU_metric: 0.0764
# Epoch 4/20
# 43/43 [==============================] - ETA: 0s - loss: 18.6273 - labels_loss: 1.3478 - bounding_box_loss: 17.2795 - labels_accuracy: 0.6628 - bounding_box_IoU_metric: 0.0865
# Epoch 4: val_loss improved from 17.75670 to 16.83047, saving model to models/scratch_cnn_exp4_smooth-L1.h5
# 43/43 [==============================] - 56s 1s/step - loss: 18.6273 - labels_loss: 1.3478 - bounding_box_loss: 17.2795 - labels_accuracy: 0.6628 - bounding_box_IoU_metric: 0.0865 - val_loss: 16.8305 - val_labels_loss: 0.9911 - val_bounding_box_loss: 15.8394 - val_labels_accuracy: 0.4781 - val_bounding_box_IoU_metric: 0.0933
# Epoch 5/20
# 43/43 [==============================] - ETA: 0s - loss: 17.4280 - labels_loss: 1.1862 - bounding_box_loss: 16.2418 - labels_accuracy: 0.6672 - bounding_box_IoU_metric: 0.1018
# Epoch 5: val_loss did not improve from 16.83047
# 43/43 [==============================] - 51s 1s/step - loss: 17.4280 - labels_loss: 1.1862 - bounding_box_loss: 16.2418 - labels_accuracy: 0.6672 - bounding_box_IoU_metric: 0.1018 - val_loss: 18.8884 - val_labels_loss: 1.3027 - val_bounding_box_loss: 17.5857 - val_labels_accuracy: 0.7522 - val_bounding_box_IoU_metric: 0.0660
# Epoch 6/20
# 43/43 [==============================] - ETA: 0s - loss: 16.0575 - labels_loss: 1.1063 - bounding_box_loss: 14.9513 - labels_accuracy: 0.7044 - bounding_box_IoU_metric: 0.1176
# Epoch 6: val_loss improved from 16.83047 to 15.88095, saving model to models/scratch_cnn_exp4_smooth-L1.h5
# 43/43 [==============================] - 50s 1s/step - loss: 16.0575 - labels_loss: 1.1063 - bounding_box_loss: 14.9513 - labels_accuracy: 0.7044 - bounding_box_IoU_metric: 0.1176 - val_loss: 15.8809 - val_labels_loss: 0.7850 - val_bounding_box_loss: 15.0959 - val_labels_accuracy: 0.7609 - val_bounding_box_IoU_metric: 0.1139
# Epoch 7/20
# 43/43 [==============================] - ETA: 0s - loss: 15.8681 - labels_loss: 0.9449 - bounding_box_loss: 14.9232 - labels_accuracy: 0.7168 - bounding_box_IoU_metric: 0.1191
# Epoch 7: val_loss improved from 15.88095 to 15.47092, saving model to models/scratch_cnn_exp4_smooth-L1.h5
# 43/43 [==============================] - 49s 1s/step - loss: 15.8681 - labels_loss: 0.9449 - bounding_box_loss: 14.9232 - labels_accuracy: 0.7168 - bounding_box_IoU_metric: 0.1191 - val_loss: 15.4709 - val_labels_loss: 1.0336 - val_bounding_box_loss: 14.4373 - val_labels_accuracy: 0.7493 - val_bounding_box_IoU_metric: 0.1451
# Epoch 8/20
# 43/43 [==============================] - ETA: 0s - loss: 14.9087 - labels_loss: 0.8858 - bounding_box_loss: 14.0230 - labels_accuracy: 0.7336 - bounding_box_IoU_metric: 0.1352
# Epoch 8: val_loss improved from 15.47092 to 15.11092, saving model to models/scratch_cnn_exp4_smooth-L1.h5
# 43/43 [==============================] - 49s 1s/step - loss: 14.9087 - labels_loss: 0.8858 - bounding_box_loss: 14.0230 - labels_accuracy: 0.7336 - bounding_box_IoU_metric: 0.1352 - val_loss: 15.1109 - val_labels_loss: 1.1777 - val_bounding_box_loss: 13.9332 - val_labels_accuracy: 0.7638 - val_bounding_box_IoU_metric: 0.1518
# Epoch 9/20
# 43/43 [==============================] - ETA: 0s - loss: 14.2463 - labels_loss: 0.8521 - bounding_box_loss: 13.3941 - labels_accuracy: 0.7737 - bounding_box_IoU_metric: 0.1576
# Epoch 9: val_loss improved from 15.11092 to 14.41590, saving model to models/scratch_cnn_exp4_smooth-L1.h5
# 43/43 [==============================] - 49s 1s/step - loss: 14.2463 - labels_loss: 0.8521 - bounding_box_loss: 13.3941 - labels_accuracy: 0.7737 - bounding_box_IoU_metric: 0.1576 - val_loss: 14.4159 - val_labels_loss: 0.8577 - val_bounding_box_loss: 13.5582 - val_labels_accuracy: 0.6676 - val_bounding_box_IoU_metric: 0.1541
# Epoch 10/20
# 43/43 [==============================] - ETA: 0s - loss: 13.7743 - labels_loss: 0.8573 - bounding_box_loss: 12.9170 - labels_accuracy: 0.7701 - bounding_box_IoU_metric: 0.1597
# Epoch 10: val_loss did not improve from 14.41590
# 43/43 [==============================] - 51s 1s/step - loss: 13.7743 - labels_loss: 0.8573 - bounding_box_loss: 12.9170 - labels_accuracy: 0.7701 - bounding_box_IoU_metric: 0.1597 - val_loss: 15.6188 - val_labels_loss: 0.9042 - val_bounding_box_loss: 14.7146 - val_labels_accuracy: 0.6735 - val_bounding_box_IoU_metric: 0.1036
# Epoch 11/20
# 43/43 [==============================] - ETA: 0s - loss: 13.2013 - labels_loss: 0.7827 - bounding_box_loss: 12.4185 - labels_accuracy: 0.7920 - bounding_box_IoU_metric: 0.1698
# Epoch 11: val_loss did not improve from 14.41590
# 43/43 [==============================] - 49s 1s/step - loss: 13.2013 - labels_loss: 0.7827 - bounding_box_loss: 12.4185 - labels_accuracy: 0.7920 - bounding_box_IoU_metric: 0.1698 - val_loss: 14.7953 - val_labels_loss: 1.5817 - val_bounding_box_loss: 13.2137 - val_labels_accuracy: 0.7405 - val_bounding_box_IoU_metric: 0.1657
# Epoch 12/20
# 43/43 [==============================] - ETA: 0s - loss: 12.8184 - labels_loss: 0.6381 - bounding_box_loss: 12.1803 - labels_accuracy: 0.8197 - bounding_box_IoU_metric: 0.1770
# Epoch 12: val_loss did not improve from 14.41590
# 43/43 [==============================] - 49s 1s/step - loss: 12.8184 - labels_loss: 0.6381 - bounding_box_loss: 12.1803 - labels_accuracy: 0.8197 - bounding_box_IoU_metric: 0.1770 - val_loss: 15.4076 - val_labels_loss: 1.3066 - val_bounding_box_loss: 14.1010 - val_labels_accuracy: 0.6880 - val_bounding_box_IoU_metric: 0.1770
# Epoch 13/20
# 43/43 [==============================] - ETA: 0s - loss: 12.3781 - labels_loss: 0.6050 - bounding_box_loss: 11.7731 - labels_accuracy: 0.8314 - bounding_box_IoU_metric: 0.1891
# Epoch 13: val_loss did not improve from 14.41590
# 43/43 [==============================] - 49s 1s/step - loss: 12.3781 - labels_loss: 0.6050 - bounding_box_loss: 11.7731 - labels_accuracy: 0.8314 - bounding_box_IoU_metric: 0.1891 - val_loss: 14.9297 - val_labels_loss: 2.2365 - val_bounding_box_loss: 12.6932 - val_labels_accuracy: 0.7609 - val_bounding_box_IoU_metric: 0.1811
# Epoch 14/20
# 43/43 [==============================] - ETA: 0s - loss: 11.9302 - labels_loss: 0.5624 - bounding_box_loss: 11.3678 - labels_accuracy: 0.8416 - bounding_box_IoU_metric: 0.1849
# Epoch 14: val_loss did not improve from 14.41590
# 43/43 [==============================] - 51s 1s/step - loss: 11.9302 - labels_loss: 0.5624 - bounding_box_loss: 11.3678 - labels_accuracy: 0.8416 - bounding_box_IoU_metric: 0.1849 - val_loss: 15.6951 - val_labels_loss: 1.2582 - val_bounding_box_loss: 14.4369 - val_labels_accuracy: 0.6560 - val_bounding_box_IoU_metric: 0.1153
# Epoch 15/20
# 43/43 [==============================] - ETA: 0s - loss: 11.4012 - labels_loss: 0.5126 - bounding_box_loss: 10.8885 - labels_accuracy: 0.8577 - bounding_box_IoU_metric: 0.1994
# Epoch 15: val_loss did not improve from 14.41590
# 43/43 [==============================] - 49s 1s/step - loss: 11.4012 - labels_loss: 0.5126 - bounding_box_loss: 10.8885 - labels_accuracy: 0.8577 - bounding_box_IoU_metric: 0.1994 - val_loss: 14.8198 - val_labels_loss: 1.2373 - val_bounding_box_loss: 13.5825 - val_labels_accuracy: 0.7055 - val_bounding_box_IoU_metric: 0.1285
# Epoch 16/20
# 43/43 [==============================] - ETA: 0s - loss: 11.1219 - labels_loss: 0.4671 - bounding_box_loss: 10.6548 - labels_accuracy: 0.8723 - bounding_box_IoU_metric: 0.2102
# Epoch 16: val_loss improved from 14.41590 to 13.97643, saving model to models/scratch_cnn_exp4_smooth-L1.h5
# 43/43 [==============================] - 49s 1s/step - loss: 11.1219 - labels_loss: 0.4671 - bounding_box_loss: 10.6548 - labels_accuracy: 0.8723 - bounding_box_IoU_metric: 0.2102 - val_loss: 13.9764 - val_labels_loss: 1.3294 - val_bounding_box_loss: 12.6471 - val_labels_accuracy: 0.7347 - val_bounding_box_IoU_metric: 0.1588
# Epoch 17/20
# 43/43 [==============================] - ETA: 0s - loss: 10.4016 - labels_loss: 0.4730 - bounding_box_loss: 9.9287 - labels_accuracy: 0.8832 - bounding_box_IoU_metric: 0.2219
# Epoch 17: val_loss did not improve from 13.97643
# 43/43 [==============================] - 49s 1s/step - loss: 10.4016 - labels_loss: 0.4730 - bounding_box_loss: 9.9287 - labels_accuracy: 0.8832 - bounding_box_IoU_metric: 0.2219 - val_loss: 16.2912 - val_labels_loss: 1.0973 - val_bounding_box_loss: 15.1939 - val_labels_accuracy: 0.7289 - val_bounding_box_IoU_metric: 0.0885
# Epoch 18/20
# 43/43 [==============================] - ETA: 0s - loss: 10.4652 - labels_loss: 0.3954 - bounding_box_loss: 10.0698 - labels_accuracy: 0.8942 - bounding_box_IoU_metric: 0.2175
# Epoch 18: val_loss did not improve from 13.97643
# 43/43 [==============================] - 49s 1s/step - loss: 10.4652 - labels_loss: 0.3954 - bounding_box_loss: 10.0698 - labels_accuracy: 0.8942 - bounding_box_IoU_metric: 0.2175 - val_loss: 14.6139 - val_labels_loss: 1.7621 - val_bounding_box_loss: 12.8518 - val_labels_accuracy: 0.7464 - val_bounding_box_IoU_metric: 0.1930
# Epoch 19/20
# 43/43 [==============================] - ETA: 0s - loss: 9.6608 - labels_loss: 0.3966 - bounding_box_loss: 9.2641 - labels_accuracy: 0.9153 - bounding_box_IoU_metric: 0.2385
# Epoch 19: val_loss did not improve from 13.97643
# 43/43 [==============================] - 51s 1s/step - loss: 9.6608 - labels_loss: 0.3966 - bounding_box_loss: 9.2641 - labels_accuracy: 0.9153 - bounding_box_IoU_metric: 0.2385 - val_loss: 14.6851 - val_labels_loss: 1.5225 - val_bounding_box_loss: 13.1625 - val_labels_accuracy: 0.6880 - val_bounding_box_IoU_metric: 0.1723
# Epoch 20/20
# 43/43 [==============================] - ETA: 0s - loss: 9.6098 - labels_loss: 0.3198 - bounding_box_loss: 9.2900 - labels_accuracy: 0.9219 - bounding_box_IoU_metric: 0.2390
# Epoch 20: val_loss did not improve from 13.97643
# 43/43 [==============================] - 49s 1s/step - loss: 9.6098 - labels_loss: 0.3198 - bounding_box_loss: 9.2900 - labels_accuracy: 0.9219 - bounding_box_IoU_metric: 0.2390 - val_loss: 14.0373 - val_labels_loss: 1.6061 - val_bounding_box_loss: 12.4312 - val_labels_accuracy: 0.7085 - val_bounding_box_IoU_metric: 0.1812

# %%
#plot the history of the training

plt.figure(figsize=(12,5))
plt.title('labels loss')
plt.plot(history.history['labels_loss'],'bo-',label = 'train_labels_loss')
plt.plot(history.history['val_labels_loss'],'b-',label = 'val_labels_loss')
plt.ylim(0, 2)
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('bbox loss')
plt.plot(history.history['bounding_box_loss'],'bo-',label = 'train_bounding_box_loss')
plt.plot(history.history['val_bounding_box_loss'],'b-',label = 'val_bounding_box_loss')
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('total loss')
plt.plot(history.history['loss'],'bo-',label = 'train_loss')
plt.plot(history.history['val_loss'],'b-',label = 'val_loss')
plt.legend()
plt.show()


plt.figure(figsize=(12,5))
plt.title('accuracy')
plt.plot(history.history['labels_accuracy'],'bo-',label = 'train_labels_accuracy')
plt.plot(history.history['val_labels_accuracy'],'b-',label = 'val_labels_accuracy')
plt.legend()
plt.show()

plt.figure(figsize=(12,5))
plt.title('IoU scaled in [0,1]')
plt.plot(history.history['bounding_box_IoU_metric'],'bo-',label = 'train_bounding_box_IoU_metric')
plt.plot(history.history['val_bounding_box_IoU_metric'],'b-',label = 'val_bounding_box_IoU_metric')
plt.legend()
plt.show()

# %%
# delete the current model
del model

# load the model saved by the early stopping callback
# here we need to set compile to False for a bug in Keras related to the handling of custom losses
model = load_model(os.path.join(model_dir, experiment), custom_objects={"SmoothL1Loss": smooth_L1_loss , "IoU_metric": IoU_metric}, compile=False)

# we recompile the model after the loading of the model because it was needed to call the evaluate method
model.compile(
    optimizer=keras.optimizers.RMSprop(1e-3),
    loss={
        "bounding_box": smooth_L1_loss,
        "labels": keras.losses.CategoricalCrossentropy(),
    },
    loss_weights={"labels": 1.0, "bounding_box": 1.0},
    metrics={'labels':'accuracy', 'bounding_box': [IoU_metric]}
)

#evaluate the model on the test set
model.evaluate({"input": feature_test_set},
               {"labels": labels_test_set, "bounding_box": bounding_box_test_set}, 
               return_dict=True)
# Out:
# 14/14 [==============================] - 5s 280ms/step - loss: 13.9401 - labels_loss: 1.7168 - bounding_box_loss: 12.2233 - labels_accuracy: 0.7079 - bounding_box_IoU_metric: 0.1550
# {'loss': 13.94007396697998,
#  'labels_loss': 1.7168017625808716,
#  'bounding_box_loss': 12.223273277282715,
#  'labels_accuracy': 0.7079439163208008,
#  'bounding_box_IoU_metric': 0.15500329434871674}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
# create and plot the confusion matrix
predictions = model(feature_test_set)
result = confusion_matrix(tf.math.argmax(labels_test_set, axis=1), tf.math.argmax(predictions[0], axis=1), normalize='pred')
disp = ConfusionMatrixDisplay(confusion_matrix=result, display_labels=['without mask', 'with mask'])
disp.plot()
plt.show()

# %%
# save the model to google drive
# !cp ./models/scratch_cnn_exp4_smooth-L1.h5 /content/drive/MyDrive/CIDL_Project/models/

# %%
# verify that the model was uploaded to drive
drive_dir_model = "/content/drive/MyDrive/CIDL_Project/models/"

# same problem as before
model = load_model(os.path.join(model_dir, experiment), custom_objects={"SmoothL1Loss": smooth_L1_loss , "IoU_metric": IoU_metric}, compile=False)

model.compile(
    optimizer=keras.optimizers.RMSprop(1e-3),
    loss={
        "bounding_box": smooth_L1_loss,
        "labels": keras.losses.CategoricalCrossentropy(),
    },
    loss_weights={"labels": 1.0, "bounding_box": 1.0},
    metrics={'labels':'accuracy', 'bounding_box': [IoU_metric]}
)
model.evaluate({"input": feature_test_set},
               {"labels": labels_test_set, "bounding_box": bounding_box_test_set}, 
               return_dict=True)
# Out:
# 14/14 [==============================] - 5s 283ms/step - loss: 13.9401 - labels_loss: 1.7168 - bounding_box_loss: 12.2233 - labels_accuracy: 0.7079 - bounding_box_IoU_metric: 0.1550
# {'loss': 13.94007396697998,
#  'labels_loss': 1.7168017625808716,
#  'bounding_box_loss': 12.223273277282715,
#  'labels_accuracy': 0.7079439163208008,
#  'bounding_box_IoU_metric': 0.15500329434871674}
